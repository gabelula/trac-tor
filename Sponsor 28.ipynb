# %%
# All tickets for Sponsor 31
# Query https://trac.torproject.org/projects/tor/query?status=accepted&status=assigned&status=closed&status=merge_ready&status=needs_information&status=needs_review&status=needs_revision&status=new&status=reopened&sponsor=%5ESponsor28&col=id&col=summary&col=sponsor&col=status&col=owner&col=type&col=priority&col=milestone&col=component&col=actualpoints&col=parent&col=points&order=sponsor

# I NEED TO FILTER BY network-roadmap keyword but still not doing it because not all tickets in the roadmap are tagged

csv_path='/Users/gaba/Code/torproject/trac/datasets/S28_tickets.csv'

import pandas as pd
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np

csv_file = pd.read_csv(csv_path)

# %%
open_tickets = csv_file.query('Status!="closed"')
close_tickets = csv_file.query('Status=="closed"')

# %%
################################## FOR CLOSED TICKETS ##################################

# which type of tickets were closed
close_tickets['Type'].value_counts().plot.barh()

# %%
close_tickets['Priority'].value_counts().plot.barh()

# %%
# who completed them
close_tickets['Owner'].value_counts().plot.barh()

# %%
################################## FOR OPEN TICKETS ##################################
# how is the priority on open tickets
open_tickets['Priority'].value_counts().plot.barh()

# %%
open_tickets.query('Priority =="Very High"')
# Out:
#        id                                            Summary         Sponsor  \
# 20   7349  Obfsbridges should be able to "disable" their ...   Sponsor28-can
# 46  19001                         Tor Browser with Snowflake  Sponsor28-must
#
#    Status Owner     Type   Priority         Milestone  \
# 20    new   NaN  project  Very High  Tor: unspecified
# 46    new   NaN  project  Very High               NaN
#
#                   Component  Actual Points Parent ID  Points
# 20             Core Tor/Tor            NaN       NaN    10.0
# 46  Circumvention/Snowflake            NaN       NaN     NaN

# %%
# which type of tickets
open_tickets['Type'].value_counts().plot.barh()

# %%
# which components we are changing
open_tickets['Component'].value_counts().plot.barh()

# %%
# who is assigned
open_tickets['Owner'].value_counts().plot.barh()

# %%
open_tickets.query('Owner=="tbb-team"')
# Out:
#        id                                            Summary        Sponsor  \
# 28  28803  Integrate building pluggable transports for An...  Sponsor28-can
#
#             Status     Owner  Type Priority Milestone  \
# 28  needs_revision  tbb-team  task     High       NaN
#
#                    Component  Actual Points Parent ID  Points
# 28  Applications/Tor Browser            NaN       NaN     NaN

# %%
# how many must tickets versus 'can be done'
open_tickets['Sponsor'].value_counts().plot.barh()

# %%
open_tickets.query('Sponsor=="Sponsor28-must"')
# Out:
#        id                                            Summary         Sponsor  \
# 45   5304  Obfsproxy should respect OutboundBindAddress i...  Sponsor28-must
# 46  19001                         Tor Browser with Snowflake  Sponsor28-must
# 49  25429  Need something better than client's `checkForS...  Sponsor28-must
# 52  28672            Android reproducible build of Snowflake  Sponsor28-must
# 53  28849  Handle dormant mode in process library and for...  Sponsor28-must
# 55  29111               Optional heartbeat message from PT's  Sponsor28-must
# 56  29128  Place complete obfs4 bridge line in accessible...  Sponsor28-must
# 57  29206  New design for client -- server protocol for S...  Sponsor28-must
# 58  29207  New design for broker -- proxy protocol for sn...  Sponsor28-must
# 59  29245  Tor 0.4 eventually hits "Delaying directory fe...  Sponsor28-must
# 60  29258   Provide an IPv6 address for the Snowflake broker  Sponsor28-must
# 61  29259            Ensure high test coverage for Snowflake  Sponsor28-must
# 66  29285  Improve the PT spec and how PTs interface with...  Sponsor28-must
# 67  29293  New Design for client -- broker protocol for S...  Sponsor28-must
# 69  30471              Improve UX for obfs4 bridge operation  Sponsor28-must
# 72  30716             Improve the obfs4 obfuscation protocol  Sponsor28-must
# 73  30986  Understand the "long tail" of unclassifiable n...  Sponsor28-must
# 74  31103  Support ORPort picking a random port that pers...  Sponsor28-must
#
#                Status   Owner         Type   Priority         Milestone  \
# 45        merge_ready     NaN       defect     Medium               NaN
# 46                new     NaN      project  Very High               NaN
# 49           assigned  cohosh       defect     Medium               NaN
# 52     needs_revision     NaN      project     Medium               NaN
# 53  needs_information     NaN  enhancement       High  Tor: unspecified
# 55                new     NaN  enhancement        Low  Tor: unspecified
# 56                new     NaN       defect     Medium  Tor: unspecified
# 57       needs_review  cohosh         task     Medium               NaN
# 58        merge_ready  cohosh  enhancement       High               NaN
# 59                new     NaN       defect     Medium  Tor: unspecified
# 60        merge_ready     dcf         task     Medium               NaN
# 61           assigned  cohosh         task     Medium               NaN
# 66           assigned     phw      project       High               NaN
# 67                new     NaN         task       High               NaN
# 69                new     NaN      project     Medium               NaN
# 72           assigned     phw         task       High               NaN
# 73           assigned     phw      project     Medium               NaN
# 74                new     NaN  enhancement     Medium               NaN
#
#                             Component  Actual Points Parent ID  Points
# 45                Circumvention/Obfs4           1.25    #30471     1.0
# 46            Circumvention/Snowflake            NaN       NaN     NaN
# 49            Circumvention/Snowflake            NaN       NaN     NaN
# 52            Circumvention/Snowflake            NaN    #30318     NaN
# 53                       Core Tor/Tor           2.50       NaN     3.0
# 55  Circumvention/Pluggable transport            NaN       NaN     NaN
# 56                       Core Tor/Tor            NaN    #30471     NaN
# 57            Circumvention/Snowflake            NaN       NaN     6.0
# 58            Circumvention/Snowflake           2.00       NaN     5.0
# 59                       Core Tor/Tor            NaN       NaN     NaN
# 60            Circumvention/Snowflake            NaN       NaN     NaN
# 61            Circumvention/Snowflake            NaN       NaN     NaN
# 66  Circumvention/Pluggable transport            NaN       NaN    15.0
# 67            Circumvention/Snowflake            NaN       NaN     NaN
# 69                Circumvention/Obfs4            NaN       NaN     NaN
# 72                Circumvention/Obfs4            NaN       NaN    20.0
# 73                      Circumvention            NaN    #30716     5.0
# 74                       Core Tor/Tor            NaN    #30471     1.0

# %%
# how many sponsor28-must tickets are already done and how many still need to be finish
csv_file.query('Sponsor=="Sponsor28-must"')['Status'].value_counts()
# Out:
# closed               12
# new                   7
# assigned              5
# merge_ready           3
# needs_review          1
# needs_revision        1
# needs_information     1
# Name: Status, dtype: int64

# %%
# what about the 'could be done' tickets
csv_file.query('Sponsor=="Sponsor28-can"')['Status'].value_counts().plot.barh()

# %%
# are all of the open tickets estimated?
csv_file[csv_file.Points.isnull()].query('Status!="closed"')
# Out:
#        id                                            Summary         Sponsor  \
# 12  31201  Allow webextension users to specify how many r...       Sponsor28
# 17  31804       Authentication for proxy--bridge connections       Sponsor28
# 19  31982                               Problems with Gettor       Sponsor28
# 22  25593         Broker needs better resilience against DoS   Sponsor28-can
# 23  25595  Test suite for Snowflake on various NAT topolo...   Sponsor28-can
# 28  28803  Integrate building pluggable transports for An...   Sponsor28-can
# 34  29287                         Have backup PT in pipeline   Sponsor28-can
# 37  30368  Run some tests to check reachability of snowfl...   Sponsor28-can
# 46  19001                         Tor Browser with Snowflake  Sponsor28-must
# 49  25429  Need something better than client's `checkForS...  Sponsor28-must
# 52  28672            Android reproducible build of Snowflake  Sponsor28-must
# 55  29111               Optional heartbeat message from PT's  Sponsor28-must
# 56  29128  Place complete obfs4 bridge line in accessible...  Sponsor28-must
# 59  29245  Tor 0.4 eventually hits "Delaying directory fe...  Sponsor28-must
# 60  29258   Provide an IPv6 address for the Snowflake broker  Sponsor28-must
# 61  29259            Ensure high test coverage for Snowflake  Sponsor28-must
# 67  29293  New Design for client -- broker protocol for S...  Sponsor28-must
# 69  30471              Improve UX for obfs4 bridge operation  Sponsor28-must
#
#             Status     Owner         Type   Priority         Milestone  \
# 12             new       NaN       defect     Medium               NaN
# 17             new       NaN       defect     Medium               NaN
# 19        assigned      hiro       defect     Medium               NaN
# 22             new       NaN       defect     Medium               NaN
# 23             new       NaN       defect     Medium               NaN
# 28  needs_revision  tbb-team         task       High               NaN
# 34             new       NaN      project        Low               NaN
# 37        accepted    cohosh         task     Medium               NaN
# 46             new       NaN      project  Very High               NaN
# 49        assigned    cohosh       defect     Medium               NaN
# 52  needs_revision       NaN      project     Medium               NaN
# 55             new       NaN  enhancement        Low  Tor: unspecified
# 56             new       NaN       defect     Medium  Tor: unspecified
# 59             new       NaN       defect     Medium  Tor: unspecified
# 60     merge_ready       dcf         task     Medium               NaN
# 61        assigned    cohosh         task     Medium               NaN
# 67             new       NaN         task       High               NaN
# 69             new       NaN      project     Medium               NaN
#
#                             Component  Actual Points Parent ID  Points
# 12            Circumvention/Snowflake            NaN       NaN     NaN
# 17            Circumvention/Snowflake            NaN       NaN     NaN
# 19                Applications/GetTor            NaN       NaN     NaN
# 22            Circumvention/Snowflake            NaN       NaN     NaN
# 23            Circumvention/Snowflake            NaN       NaN     NaN
# 28           Applications/Tor Browser            NaN       NaN     NaN
# 34  Circumvention/Pluggable transport            NaN       NaN     NaN
# 37            Circumvention/Snowflake            NaN       NaN     NaN
# 46            Circumvention/Snowflake            NaN       NaN     NaN
# 49            Circumvention/Snowflake            NaN       NaN     NaN
# 52            Circumvention/Snowflake            NaN    #30318     NaN
# 55  Circumvention/Pluggable transport            NaN       NaN     NaN
# 56                       Core Tor/Tor            NaN    #30471     NaN
# 59                       Core Tor/Tor            NaN       NaN     NaN
# 60            Circumvention/Snowflake            NaN       NaN     NaN
# 61            Circumvention/Snowflake            NaN       NaN     NaN
# 67            Circumvention/Snowflake            NaN       NaN     NaN
# 69                Circumvention/Obfs4            NaN       NaN     NaN

# %%
# which ones are the big tickets?
open_tickets.query('Points>6')
# Out:
#        id                                            Summary         Sponsor  \
# 20   7349  Obfsbridges should be able to "disable" their ...   Sponsor28-can
# 27  26923  Intent to create Pluggable Transport: HTTPS proxy   Sponsor28-can
# 33  29267                        CI for pluggable transports   Sponsor28-can
# 66  29285  Improve the PT spec and how PTs interface with...  Sponsor28-must
# 72  30716             Improve the obfs4 obfuscation protocol  Sponsor28-must
#
#       Status Owner     Type   Priority         Milestone  \
# 20       new   NaN  project  Very High  Tor: unspecified
# 27       new   NaN  project     Medium               NaN
# 33       new   NaN  project     Medium               NaN
# 66  assigned   phw  project       High               NaN
# 72  assigned   phw     task       High               NaN
#
#                             Component  Actual Points Parent ID  Points
# 20                       Core Tor/Tor            NaN       NaN    10.0
# 27  Circumvention/Pluggable transport            NaN       NaN    30.0
# 33                      Circumvention            NaN       NaN    13.0
# 66  Circumvention/Pluggable transport            NaN       NaN    15.0
# 72                Circumvention/Obfs4            NaN       NaN    20.0

# %%
# how many points still need to be done
points_to_go = open_tickets.filter(['Points']).sum()

points_to_go/3  # thinking 3 days per week for 1 developer

# starting June: we have until december:  24 semanas  
# ---> We will need at least 2.5 developers to complete 48 weeks of tickets in this sponsor
# ---> There are -12 points
# Out:
# Points    47.166667
# dtype: float64

# %%
# how long the review tickets have been last modified
open_tickets.query('Status=="needs_review"').filter(['id', 'Summary','Modified', 'Owner', 'Reviewer'])
# Out:
#        id                                            Summary   Owner
# 2   30867  Write proxy-go tests to cover existing impleme...  cohosh
# 24  25601  Multiplex - one snowflake proxy should be able...     NaN
# 57  29206  New design for client -- server protocol for S...  cohosh
