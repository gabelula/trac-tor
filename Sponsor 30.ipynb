# %%
# All tickets for Sponsor 31
# Query https://trac.torproject.org/projects/tor/query?status=accepted&status=assigned&status=closed&status=merge_ready&status=needs_information&status=needs_review&status=needs_revision&status=new&status=reopened&sponsor=%5ESponsor30&col=id&col=summary&col=sponsor&col=status&col=owner&col=type&col=priority&col=milestone&col=component&col=actualpoints&col=parent&col=points&order=sponsor

# I NEED TO FILTER BY network-roadmap keyword but still not doing it because not all tickets in the roadmap are tagged

csv_path='/Users/gaba/Code/torproject/trac/datasets/S30_tickets.csv'

import pandas as pd
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np

csv_file = pd.read_csv(csv_path)

# %%
open_tickets = csv_file.query('Status!="closed"')
close_tickets = csv_file.query('Status=="closed"')

# %%
################################## FOR CLOSED TICKETS ##################################

# which type of tickets were closed
close_tickets['Type'].value_counts().plot.barh()

# %%
close_tickets['Priority'].value_counts().plot.barh()

# %%
# who completed them
close_tickets['Owner'].value_counts().plot.barh()

# %%
################################## FOR OPEN TICKETS ##################################
# how is the priority on open tickets
open_tickets['Priority'].value_counts().plot.barh()

# %%
open_tickets.query('Priority =="High"')
# Out:
#        id                                            Summary         Sponsor  \
# 5    5211  Discuss other ways for the bridge authority to...   Sponsor30-can
# 6    7144  Implement Bridge Guards and other anti-enumera...   Sponsor30-can
# 11  11222  Inform user if reachable bridges drop below a ...   Sponsor30-can
# 12  11330  Create a Hash Ring For Each Allowed Domain in ...   Sponsor30-can
# 13  12089  BridgedDB can be forced to email arbitrary ema...   Sponsor30-can
# 14  12505                      Refactor BridgeDB's hashrings   Sponsor30-can
# 20  16564  WIP: Reject bridge descriptors posted to non-b...   Sponsor30-can
# 38  29249                     Assessment of moat for bridges   Sponsor30-can
# 53  30767  Custom obfs4 bridge does not work on Tor Brows...   Sponsor30-can
# 67  31873          Create new bridge distribution mechanisms   Sponsor30-can
# 72  10802               Getting bridges only for port 80,443  Sponsor30-must
# 73  12802  BridgeDB needs Nagios checks for the Email Dis...  Sponsor30-must
# 74  12957  Translation instruction about accesskey should...  Sponsor30-must
#
#                Status     Owner         Type Priority         Milestone  \
# 5            assigned       NaN         task     High  Tor: unspecified
# 6                 new       NaN      project     High  Tor: unspecified
# 11  needs_information     brade       defect     High               NaN
# 12           assigned       NaN  enhancement     High               NaN
# 13           assigned       NaN       defect     High               NaN
# 14           assigned       NaN       defect     High               NaN
# 20     needs_revision      teor  enhancement     High  Tor: unspecified
# 38  needs_information       NaN         task     High               NaN
# 53       needs_review  tbb-team       defect     High               NaN
# 67                new       NaN      project     High               NaN
# 72           assigned       NaN  enhancement     High               NaN
# 73           assigned       NaN  enhancement     High               NaN
# 74           assigned       NaN  enhancement     High               NaN
#
#                     Component  Actual Points Parent ID  Points
# 5                Core Tor/Tor            NaN       NaN     NaN
# 6                Core Tor/Tor            NaN       NaN    10.0
# 11  Applications/Tor Launcher            NaN    #31283     NaN
# 12     Circumvention/BridgeDB            NaN    #31280     3.0
# 13     Circumvention/BridgeDB            NaN       NaN     NaN
# 14     Circumvention/BridgeDB            NaN       NaN     5.0
# 20               Core Tor/Tor            1.0       NaN     1.0
# 38     Circumvention/BridgeDB            NaN    #31280     5.0
# 53   Applications/Tor Browser            NaN    #31284     0.5
# 67     Circumvention/BridgeDB            NaN    #31280    20.0
# 72     Circumvention/BridgeDB            NaN    #31280     2.0
# 73     Circumvention/BridgeDB            NaN    #30152     5.0
# 74     Circumvention/BridgeDB            NaN       NaN     1.0

# %%
# which type of tickets
open_tickets['Type'].value_counts().plot.barh()

# %%
# which components we are changing
open_tickets['Component'].value_counts().plot.barh()

# %%
# who is assigned
open_tickets['Owner'].value_counts().plot.barh()

# %%
open_tickets.query('Owner=="teor"')
# Out:
#        id                                            Summary        Sponsor  \
# 20  16564  WIP: Reject bridge descriptors posted to non-b...  Sponsor30-can
#
#             Status Owner         Type Priority         Milestone  \
# 20  needs_revision  teor  enhancement     High  Tor: unspecified
#
#        Component  Actual Points Parent ID  Points
# 20  Core Tor/Tor            1.0       NaN     1.0

# %%
# how many must tickets versus 'can be done'
open_tickets['Sponsor'].value_counts().plot.barh()

# %%
open_tickets.query('Sponsor=="Sponsor30-must"')
# Out:
#         id                                            Summary         Sponsor  \
# 72   10802               Getting bridges only for port 80,443  Sponsor30-must
# 73   12802  BridgeDB needs Nagios checks for the Email Dis...  Sponsor30-must
# 74   12957  Translation instruction about accesskey should...  Sponsor30-must
# 75   13727  BridgeDB should not distribute Tor Browser's d...  Sponsor30-must
# 77   15404        BridgeDB's email localisation isn't working  Sponsor30-must
# 79   19332                              Add a BridgeDB module  Sponsor30-must
# 80   19774         bridges.torproject.org could use a favicon  Sponsor30-must
# 82   23839     Testing Framework for Censorship Circumvention  Sponsor30-must
# 83   24607  CAPTCHAs on BridgeDB seem to be getting more d...  Sponsor30-must
# 86   28015  Brainstorm improved ux for orgs that want to g...  Sponsor30-must
# 87   28526  Document how NGOs can run private obfs4 bridge...  Sponsor30-must
# 88   28531  Publish a snapshot of what PTs are needed for ...  Sponsor30-must
# 89   29184   Avoid giving out bridges that suffer from #28912  Sponsor30-must
# 90   29275  Get default bridges checked for reachability b...  Sponsor30-must
# 91   29277  Look into getting default Tor bridges scanned ...  Sponsor30-must
# 92   29288                                   Look into Salmon  Sponsor30-must
# 93   29296  Look into alternatives for distributing bridge...  Sponsor30-must
# 94   30317  Update howto on https://bridges.torproject.org...  Sponsor30-must
# 95   30477  Tor should self-test reachability of TCP liste...  Sponsor30-must
# 97   31265                           Sponsor 30 master ticket  Sponsor30-must
# 98   31266  Objective 1: Support censorship circumvention ...  Sponsor30-must
# 99   31267  O1.1 - Add support in OONI Probe for testing c...  Sponsor30-must
# 100  31268  Objective O2:  Ensure users in target countrie...  Sponsor30-must
# 101  31269  Objective O3: Improve Tor Browser experience f...  Sponsor30-must
# 102  31270  O1.2 - Analyze collected censorship circumvent...  Sponsor30-must
# 103  31271  O1.3 - Improve censorship circumvention tool m...  Sponsor30-must
# 104  31272  O1.4 - Make OONI Probe’s reporting logic more ...  Sponsor30-must
# 105  31273  O1.5 - Develop OONI Probe orchestration logic ...  Sponsor30-must
# 106  31274  O2.1 - Create an evaluation framework and coll...  Sponsor30-must
# 107  31279  O2.2 - Improve user experience and user interf...  Sponsor30-must
# 108  31280  O2.3 - Develop new and/or improve existing bri...  Sponsor30-must
# 109  31281  O2.4 - Boost security by increasing the number...  Sponsor30-must
# 110  31282  O3.1 - Research different scenarios of how hum...  Sponsor30-must
# 111  31283  O3.2 - Design the flow of how our users can by...  Sponsor30-must
# 112  31284  O3.3 - Implement final design of user flows cr...  Sponsor30-must
# 113  31870  Do an informal usability study on the "get bri...  Sponsor30-must
# 114  31871  Identify what bridge selection and distributio...  Sponsor30-must
# 115  31874              Automatically test the PTs of bridges  Sponsor30-must
# 116  31875         BridgeDB should consider a user's location  Sponsor30-must
# 117  31876  Overhaul BridgeDB's documentation and specific...  Sponsor30-must
# 118  31877  Promote workshops on how to set up a bridge at...  Sponsor30-must
# 119  31878           Look into making BridgeDB more resilient  Sponsor30-must
# 121  31936     Write usage metrics to disk before terminating  Sponsor30-must
#
#            Status     Owner         Type  Priority         Milestone  \
# 72       assigned       NaN  enhancement      High               NaN
# 73       assigned       NaN  enhancement      High               NaN
# 74       assigned       NaN  enhancement      High               NaN
# 75       assigned       NaN       defect    Medium               NaN
# 77       assigned       NaN       defect       Low               NaN
# 79   needs_review   karsten  enhancement    Medium               NaN
# 80       assigned  antonela  enhancement  Very Low               NaN
# 82            new  tbb-team       defect    Medium               NaN
# 83       assigned       NaN       defect    Medium               NaN
# 86            new  tbb-team       defect    Medium               NaN
# 87       assigned      ggus      project    Medium               NaN
# 88       assigned       phw         task    Medium               NaN
# 89            new    sysrqb  enhancement    Medium               NaN
# 90            new       NaN         task    Medium               NaN
# 91       assigned       phw         task    Medium               NaN
# 92            new       NaN         task    Medium               NaN
# 93            new       NaN      project    Medium               NaN
# 94            new    sysrqb       defect    Medium               NaN
# 95            new       NaN         task    Medium  Tor: unspecified
# 97            new       NaN      project    Medium               NaN
# 98            new       NaN      project    Medium               NaN
# 99            new       NaN       defect    Medium               NaN
# 100           new       NaN      project    Medium               NaN
# 101      assigned  antonela      project    Medium               NaN
# 102           new       NaN      project    Medium               NaN
# 103           new       NaN      project    Medium               NaN
# 104           new       NaN      project    Medium               NaN
# 105           new       NaN      project    Medium               NaN
# 106           new       NaN      project    Medium               NaN
# 107           new       NaN      project    Medium               NaN
# 108           new       NaN      project    Medium               NaN
# 109           new       NaN      project    Medium               NaN
# 110           new  antonela      project    Medium               NaN
# 111           new  antonela      project    Medium               NaN
# 112           new  tbb-team      project    Medium               NaN
# 113           new       NaN         task    Medium               NaN
# 114           new       NaN      project    Medium               NaN
# 115  needs_review       NaN       defect    Medium               NaN
# 116           new       NaN         task    Medium               NaN
# 117           new       NaN         task    Medium               NaN
# 118           new       NaN         task    Medium               NaN
# 119           new       NaN         task    Medium               NaN
# 121           new       NaN       defect    Medium               NaN
#
#                              Component  Actual Points Parent ID  Points
# 72              Circumvention/BridgeDB            NaN    #31280     2.0
# 73              Circumvention/BridgeDB            NaN    #30152     5.0
# 74              Circumvention/BridgeDB            NaN       NaN     1.0
# 75              Circumvention/BridgeDB            NaN    #31280     2.0
# 77              Circumvention/BridgeDB            NaN    #31279     2.0
# 79                   Metrics/CollecTor            NaN    #31274     8.0
# 80              Circumvention/BridgeDB            NaN    #31279     1.0
# 82            Applications/Tor Browser            NaN       NaN     NaN
# 83              Circumvention/BridgeDB            NaN    #31279     5.0
# 86            Applications/Tor Browser            NaN    #31283     NaN
# 87               Community/Tor Support            NaN    #31281     NaN
# 88                  Community/Outreach            NaN    #31279     NaN
# 89              Circumvention/BridgeDB            NaN       NaN     NaN
# 90   Circumvention/Pluggable transport            NaN       NaN     NaN
# 91   Circumvention/Pluggable transport            NaN    #31274     NaN
# 92   Circumvention/Pluggable transport            NaN       NaN     NaN
# 93   Circumvention/Pluggable transport            NaN    #31280     NaN
# 94              Circumvention/BridgeDB            NaN    #31279     NaN
# 95                        Core Tor/Tor            NaN    #30471     NaN
# 97                       Circumvention            NaN       NaN     NaN
# 98                       Circumvention            NaN    #31265     NaN
# 99                       Circumvention            NaN    #31266     NaN
# 100             Circumvention/BridgeDB            NaN    #31265     NaN
# 101                                 UX            NaN    #31265     NaN
# 102                      Circumvention            NaN    #31266     NaN
# 103                      Circumvention            NaN    #31266     NaN
# 104                      Circumvention            NaN    #31266     NaN
# 105                      Circumvention            NaN    #31266     NaN
# 106             Circumvention/BridgeDB            NaN    #31268     NaN
# 107                                 UX            NaN    #31268     NaN
# 108             Circumvention/BridgeDB            NaN    #31268     NaN
# 109             Circumvention/BridgeDB            NaN    #31268     NaN
# 110                                 UX            NaN    #31269     NaN
# 111                                 UX            NaN    #31269     NaN
# 112           Applications/Tor Browser            NaN    #31269     NaN
# 113                      Circumvention            NaN    #31279     2.0
# 114             Circumvention/BridgeDB            NaN    #31274     3.0
# 115                      Circumvention            NaN    #31280    10.0
# 116             Circumvention/BridgeDB            NaN    #31280    10.0
# 117             Circumvention/BridgeDB            NaN    #31281     3.0
# 118                      Circumvention            NaN    #31281     3.0
# 119             Circumvention/BridgeDB            NaN    #31281    10.0
# 121             Circumvention/BridgeDB            NaN    #31274     1.0

# %%
# how many sponsor31-must tickets are already done and how many still need to be finish
csv_file.query('Sponsor=="Sponsor30-must"')['Status'].value_counts()
# Out:
# new             30
# assigned        11
# closed           9
# needs_review     2
# Name: Status, dtype: int64

# %%
# what about the 'could be done' tickets
csv_file.query('Sponsor=="Sponsor30-can"')['Status'].value_counts().plot.barh()

# %%
# are all of the open tickets estimated?
csv_file[csv_file.Points.isnull()].query('Status!="closed"')
# Out:
#         id                                            Summary         Sponsor  \
# 0    30941  Need better instructions for requesting bridge...       Sponsor30
# 3    32204  Create either a query or event-based API to al...       Sponsor30
# 5     5211  Discuss other ways for the bridge authority to...   Sponsor30-can
# 9    10970                    tor-bridge-relay Debian package   Sponsor30-can
# 10   11132  Tor Launcher should suggest the use of bridges...   Sponsor30-can
# 11   11222  Inform user if reachable bridges drop below a ...   Sponsor30-can
# 13   12089  BridgedDB can be forced to email arbitrary ema...   Sponsor30-can
# 16   14638  Make it easier to add a bridge in network sett...   Sponsor30-can
# 17   14836  Can we compile in WebRTC to allow QRCode bridg...   Sponsor30-can
# 18   14837  Support QRCode bridge entry and sharing in Tor...   Sponsor30-can
# 21   17449      Test bridges we ship in Tor Browser regularly   Sponsor30-can
# 23   18113  Dynamically allocate clients to default Tor Br...   Sponsor30-can
# 24   19693           Portuguese (pt_PT) translation to GetTor   Sponsor30-can
# 28   23838      Use OONI to inform Tor Launcher user workflow   Sponsor30-can
# 29   23971  implement multi-step progress bar for new Tor ...   Sponsor30-can
# 30   24527  Inform users in Tor Launcher of which settings...   Sponsor30-can
# 31   25431  "Tor is censored in my country" does not cover...   Sponsor30-can
# 32   25528  When ClientTransportPlugin is missing, tor con...   Sponsor30-can
# 35   28555  Assess methodology for modern privcount Tor us...   Sponsor30-can
# 36   28556  Detect other installed circumvention tools and...   Sponsor30-can
# 39   29286                               Maintain obfs4 proxy   Sponsor30-can
# 41   29590  Smarter bootstrapping for Tor Browser on Andro...   Sponsor30-can
# 42   29686  filenames conflict on case-insensitive filesys...   Sponsor30-can
# 43   29695  The captcha displayed while authenticating con...   Sponsor30-can
# 45   29863  Add disk space monitoring for snowflake infras...   Sponsor30-can
# 46   30130         Provide custom bridges in a multiline form   Sponsor30-can
# 47   30131  Disabling/enabling bridge-switch is jumping/no...   Sponsor30-can
# 48   30152             Monitor anti-censorship infrastructure   Sponsor30-can
# 49   30350  Hello, in China, currently, Tor Browser 8.5a11...   Sponsor30-can
# 50   30456            TBA - Provide bridges with a magic link   Sponsor30-can
# 54   30768  Add hashed fingerprints to torrc when configur...   Sponsor30-can
# 63   31539  FAQ page (esp connection troubleshoooting) sho...   Sponsor30-can
# 82   23839     Testing Framework for Censorship Circumvention  Sponsor30-must
# 86   28015  Brainstorm improved ux for orgs that want to g...  Sponsor30-must
# 87   28526  Document how NGOs can run private obfs4 bridge...  Sponsor30-must
# 88   28531  Publish a snapshot of what PTs are needed for ...  Sponsor30-must
# 89   29184   Avoid giving out bridges that suffer from #28912  Sponsor30-must
# 90   29275  Get default bridges checked for reachability b...  Sponsor30-must
# 91   29277  Look into getting default Tor bridges scanned ...  Sponsor30-must
# 92   29288                                   Look into Salmon  Sponsor30-must
# 93   29296  Look into alternatives for distributing bridge...  Sponsor30-must
# 94   30317  Update howto on https://bridges.torproject.org...  Sponsor30-must
# 95   30477  Tor should self-test reachability of TCP liste...  Sponsor30-must
# 97   31265                           Sponsor 30 master ticket  Sponsor30-must
# 98   31266  Objective 1: Support censorship circumvention ...  Sponsor30-must
# 99   31267  O1.1 - Add support in OONI Probe for testing c...  Sponsor30-must
# 100  31268  Objective O2:  Ensure users in target countrie...  Sponsor30-must
# 101  31269  Objective O3: Improve Tor Browser experience f...  Sponsor30-must
# 102  31270  O1.2 - Analyze collected censorship circumvent...  Sponsor30-must
# 103  31271  O1.3 - Improve censorship circumvention tool m...  Sponsor30-must
# 104  31272  O1.4 - Make OONI Probe’s reporting logic more ...  Sponsor30-must
# 105  31273  O1.5 - Develop OONI Probe orchestration logic ...  Sponsor30-must
# 106  31274  O2.1 - Create an evaluation framework and coll...  Sponsor30-must
# 107  31279  O2.2 - Improve user experience and user interf...  Sponsor30-must
# 108  31280  O2.3 - Develop new and/or improve existing bri...  Sponsor30-must
# 109  31281  O2.4 - Boost security by increasing the number...  Sponsor30-must
# 110  31282  O3.1 - Research different scenarios of how hum...  Sponsor30-must
# 111  31283  O3.2 - Design the flow of how our users can by...  Sponsor30-must
# 112  31284  O3.3 - Implement final design of user flows cr...  Sponsor30-must
#
#                 Status         Owner         Type Priority         Milestone  \
# 0                  new        sysrqb       defect   Medium               NaN
# 3                  new           NaN       defect   Medium               NaN
# 5             assigned           NaN         task     High  Tor: unspecified
# 9                  new     infinity0      project   Medium               NaN
# 10                 new         brade  enhancement   Medium               NaN
# 11   needs_information         brade       defect     High               NaN
# 13            assigned           NaN       defect     High               NaN
# 16                 new      tbb-team  enhancement   Medium               NaN
# 17            assigned           NaN         task   Medium               NaN
# 18                 new         brade  enhancement   Medium               NaN
# 21                 new         boklm       defect   Medium               NaN
# 23   needs_information         brade  enhancement   Medium               NaN
# 24            assigned      emmapeel         task   Medium               NaN
# 28                 new      tbb-team       defect   Medium               NaN
# 29                 new         brade       defect   Medium               NaN
# 30                 new         brade  enhancement   Medium               NaN
# 31                 new         brade       defect   Medium               NaN
# 32                 new           NaN       defect   Medium  Tor: unspecified
# 35                 new  metrics-team         task   Medium               NaN
# 36                 new      tbb-team      project   Medium               NaN
# 39                 new           NaN         task   Medium               NaN
# 41                 new      tbb-team      project   Medium               NaN
# 42                 new        sysrqb       defect   Medium               NaN
# 43                 new      tbb-team       defect   Medium               NaN
# 45         merge_ready           NaN         task   Medium               NaN
# 46                 new      tbb-team       defect   Medium               NaN
# 47                 new      tbb-team       defect   Medium               NaN
# 48                 new           NaN      project   Medium               NaN
# 49   needs_information        cohosh       defect   Medium               NaN
# 50                 new      tbb-team  enhancement   Medium               NaN
# 54                 new      tbb-team  enhancement   Medium               NaN
# 63                 new      tbb-team  enhancement   Medium               NaN
# 82                 new      tbb-team       defect   Medium               NaN
# 86                 new      tbb-team       defect   Medium               NaN
# 87            assigned          ggus      project   Medium               NaN
# 88            assigned           phw         task   Medium               NaN
# 89                 new        sysrqb  enhancement   Medium               NaN
# 90                 new           NaN         task   Medium               NaN
# 91            assigned           phw         task   Medium               NaN
# 92                 new           NaN         task   Medium               NaN
# 93                 new           NaN      project   Medium               NaN
# 94                 new        sysrqb       defect   Medium               NaN
# 95                 new           NaN         task   Medium  Tor: unspecified
# 97                 new           NaN      project   Medium               NaN
# 98                 new           NaN      project   Medium               NaN
# 99                 new           NaN       defect   Medium               NaN
# 100                new           NaN      project   Medium               NaN
# 101           assigned      antonela      project   Medium               NaN
# 102                new           NaN      project   Medium               NaN
# 103                new           NaN      project   Medium               NaN
# 104                new           NaN      project   Medium               NaN
# 105                new           NaN      project   Medium               NaN
# 106                new           NaN      project   Medium               NaN
# 107                new           NaN      project   Medium               NaN
# 108                new           NaN      project   Medium               NaN
# 109                new           NaN      project   Medium               NaN
# 110                new      antonela      project   Medium               NaN
# 111                new      antonela      project   Medium               NaN
# 112                new      tbb-team      project   Medium               NaN
#
#                                       Component  Actual Points Parent ID  \
# 0                        Circumvention/BridgeDB            NaN    #31279
# 3                                  Core Tor/Tor            NaN    #31279
# 5                                  Core Tor/Tor            NaN       NaN
# 9             Circumvention/Pluggable transport            NaN       NaN
# 10                    Applications/Tor Launcher            NaN    #31283
# 11                    Applications/Tor Launcher            NaN    #31283
# 13                       Circumvention/BridgeDB            NaN       NaN
# 16                     Applications/Tor Browser            NaN    #31283
# 17                     Applications/Tor Browser            NaN    #31283
# 18                    Applications/Tor Launcher            NaN    #31283
# 21   Applications/Quality Assurance and Testing            NaN       NaN
# 23                    Applications/Tor Launcher            NaN       NaN
# 24                          Applications/GetTor            NaN    #28233
# 28                     Applications/Tor Browser            NaN    #31283
# 29                    Applications/Tor Launcher            NaN    #31283
# 30                    Applications/Tor Launcher            NaN    #31283
# 31                    Applications/Tor Launcher            NaN    #31283
# 32                                 Core Tor/Tor            NaN       NaN
# 35                             Metrics/Analysis            NaN       NaN
# 36                     Applications/Tor Browser            NaN    #31283
# 39                          Circumvention/Obfs4            NaN       NaN
# 41                     Applications/Tor Browser            NaN    #31283
# 42                       Circumvention/BridgeDB            NaN       NaN
# 43                     Applications/Tor Browser            NaN    #31268
# 45                      Circumvention/Snowflake            NaN    #30152
# 46                     Applications/Tor Browser            NaN    #31284
# 47                     Applications/Tor Browser            NaN    #31284
# 48                                Circumvention            NaN    #31274
# 49                      Circumvention/Snowflake            NaN    #31282
# 50                     Applications/Tor Browser            NaN    #31283
# 54                     Applications/Tor Browser            NaN       NaN
# 63                     Applications/Tor Browser            NaN       NaN
# 82                     Applications/Tor Browser            NaN       NaN
# 86                     Applications/Tor Browser            NaN    #31283
# 87                        Community/Tor Support            NaN    #31281
# 88                           Community/Outreach            NaN    #31279
# 89                       Circumvention/BridgeDB            NaN       NaN
# 90            Circumvention/Pluggable transport            NaN       NaN
# 91            Circumvention/Pluggable transport            NaN    #31274
# 92            Circumvention/Pluggable transport            NaN       NaN
# 93            Circumvention/Pluggable transport            NaN    #31280
# 94                       Circumvention/BridgeDB            NaN    #31279
# 95                                 Core Tor/Tor            NaN    #30471
# 97                                Circumvention            NaN       NaN
# 98                                Circumvention            NaN    #31265
# 99                                Circumvention            NaN    #31266
# 100                      Circumvention/BridgeDB            NaN    #31265
# 101                                          UX            NaN    #31265
# 102                               Circumvention            NaN    #31266
# 103                               Circumvention            NaN    #31266
# 104                               Circumvention            NaN    #31266
# 105                               Circumvention            NaN    #31266
# 106                      Circumvention/BridgeDB            NaN    #31268
# 107                                          UX            NaN    #31268
# 108                      Circumvention/BridgeDB            NaN    #31268
# 109                      Circumvention/BridgeDB            NaN    #31268
# 110                                          UX            NaN    #31269
# 111                                          UX            NaN    #31269
# 112                    Applications/Tor Browser            NaN    #31269
#
#      Points
# 0       NaN
# 3       NaN
# 5       NaN
# 9       NaN
# 10      NaN
# 11      NaN
# 13      NaN
# 16      NaN
# 17      NaN
# 18      NaN
# 21      NaN
# 23      NaN
# 24      NaN
# 28      NaN
# 29      NaN
# 30      NaN
# 31      NaN
# 32      NaN
# 35      NaN
# 36      NaN
# 39      NaN
# 41      NaN
# 42      NaN
# 43      NaN
# 45      NaN
# 46      NaN
# 47      NaN
# 48      NaN
# 49      NaN
# 50      NaN
# 54      NaN
# 63      NaN
# 82      NaN
# 86      NaN
# 87      NaN
# 88      NaN
# 89      NaN
# 90      NaN
# 91      NaN
# 92      NaN
# 93      NaN
# 94      NaN
# 95      NaN
# 97      NaN
# 98      NaN
# 99      NaN
# 100     NaN
# 101     NaN
# 102     NaN
# 103     NaN
# 104     NaN
# 105     NaN
# 106     NaN
# 107     NaN
# 108     NaN
# 109     NaN
# 110     NaN
# 111     NaN
# 112     NaN

# %%
# which ones are the big tickets?
open_tickets.query('Points>6')
# Out:
#         id                                            Summary         Sponsor  \
# 6     7144  Implement Bridge Guards and other anti-enumera...   Sponsor30-can
# 67   31873          Create new bridge distribution mechanisms   Sponsor30-can
# 79   19332                              Add a BridgeDB module  Sponsor30-must
# 115  31874              Automatically test the PTs of bridges  Sponsor30-must
# 116  31875         BridgeDB should consider a user's location  Sponsor30-must
# 119  31878           Look into making BridgeDB more resilient  Sponsor30-must
#
#            Status    Owner         Type Priority         Milestone  \
# 6             new      NaN      project     High  Tor: unspecified
# 67            new      NaN      project     High               NaN
# 79   needs_review  karsten  enhancement   Medium               NaN
# 115  needs_review      NaN       defect   Medium               NaN
# 116           new      NaN         task   Medium               NaN
# 119           new      NaN         task   Medium               NaN
#
#                   Component  Actual Points Parent ID  Points
# 6              Core Tor/Tor            NaN       NaN    10.0
# 67   Circumvention/BridgeDB            NaN    #31280    20.0
# 79        Metrics/CollecTor            NaN    #31274     8.0
# 115           Circumvention            NaN    #31280    10.0
# 116  Circumvention/BridgeDB            NaN    #31280    10.0
# 119  Circumvention/BridgeDB            NaN    #31281    10.0

# %%
# how many points still need to be done
points_to_go = open_tickets.filter(['Points']).sum()

points_to_go/3  # thinking 3 days per week for 1 developer

# starting June: we have until december:  24 semanas  
# ---> We will need at least 2.5 developers to complete 48 weeks of tickets in this sponsor
# ---> There are -12 points
# Out:
# Points    50.166667
# dtype: float64

# %%
# how long the review tickets have been last modified
open_tickets.query('Status=="needs_review"').filter(['id', 'Summary','Modified', 'Owner', 'Reviewer'])
# Out:
#         id                                            Summary     Owner
# 51   30501     BridgesList Preferences is an overloaded field  tbb-team
# 53   30767  Custom obfs4 bridge does not work on Tor Brows...  tbb-team
# 79   19332                              Add a BridgeDB module   karsten
# 115  31874              Automatically test the PTs of bridges       NaN
