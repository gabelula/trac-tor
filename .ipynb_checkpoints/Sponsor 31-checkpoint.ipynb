# %%
# All tickets for Sponsor 31
# Query https://trac.torproject.org/projects/tor/query?status=accepted&status=assigned&status=closed&status=merge_ready&status=needs_information&status=needs_review&status=needs_revision&status=new&status=reopened&sponsor=%5ESponsor31-must&or&status=accepted&status=assigned&status=closed&status=merge_ready&status=needs_information&status=needs_review&status=needs_revision&status=new&status=reopened&sponsor=%5ESponsor31-can&col=id&col=summary&col=sponsor&col=status&col=owner&col=type&col=priority&col=milestone&col=component&col=actualpoints&col=parent&col=points&order=sponsor

# I NEED TO FILTER BY network-roadmap keyword but still not doing it because not all tickets in the roadmap are tagged

csv_path='/Users/gaba/Code/torproject/trac/datasets/S31_tickets.csv'

import pandas as pd
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np

csv_file = pd.read_csv(csv_path)

# %%
open_tickets = csv_file.query('Status!="closed"')
close_tickets = csv_file.query('Status=="closed"')

# %%
################################## FOR CLOSED TICKETS ##################################

# which type of tickets were closed
close_tickets['Type'].value_counts().plot.barh()

# %%
close_tickets['Priority'].value_counts().plot.barh()

# %%
# who completed them
close_tickets['Owner'].value_counts().plot.barh()

# %%
################################## FOR OPEN TICKETS ##################################
# how is the priority on open tickets
open_tickets['Priority'].value_counts().plot.barh()

# %%
open_tickets.query('Priority =="Very High"')
# Out:
#         id                                            Summary        Sponsor  \
# 144  31483  token_bucket_ctr_adjust() does not convert rat...  Sponsor31-can
#
#        Status  Owner    Type   Priority           Milestone     Component  \
# 144  accepted  nickm  defect  Very High  Tor: 0.4.3.x-final  Core Tor/Tor
#
#      Actual Points Parent ID  Points
# 144            NaN       NaN     0.5

# %%
# which type of tickets
open_tickets['Type'].value_counts().plot.barh()

# %%
# which components we are changing
open_tickets['Component'].value_counts().plot.barh()

# %%
# who is assigned
open_tickets['Owner'].value_counts().plot.barh()

# %%
open_tickets.query('Owner=="asn"')
# Out:
#        id                                          Summary        Sponsor  \
# 17  29220  Update review guidelines to list best practices  Sponsor31-can
#
#       Status Owner  Type Priority           Milestone     Component  \
# 17  assigned   asn  task   Medium  Tor: 0.4.3.x-final  Core Tor/Tor
#
#     Actual Points Parent ID  Points
# 17            NaN       NaN     2.0

# %%
# how many must tickets versus 'can be done'
open_tickets['Sponsor'].value_counts().plot.barh()

# %%
open_tickets.query('Sponsor=="Sponsor31-must"')
# Out:
#         id                                            Summary         Sponsor  \
# 202  29214  Update 'tor-guts' archictecture documentation ...  Sponsor31-must
# 203  29215          Document target, modular tor architecture  Sponsor31-must
# 214  31509        config refactor: make test-stem should pass  Sponsor31-must
# 222  32206  write high-level outline of target modular tor...  Sponsor31-must
# 223  32207          write description of pub-sub architecture  Sponsor31-must
# 224  32208  write description of control subsystem archite...  Sponsor31-must
# 225  32209  write description of config subsystem architec...  Sponsor31-must
# 226  32211  write description of subsystem initialization/...  Sponsor31-must
# 227  32213  Phase 1: Disable minimal dirauth and relay opt...  Sponsor31-must
# 228  32279   Replace config_suite_offset = -1 with a constant  Sponsor31-must
#
#            Status     Owner    Type Priority           Milestone  \
# 202      accepted     nickm    task     High  Tor: 0.4.3.x-final
# 203      accepted  catalyst    task   Medium  Tor: 0.4.3.x-final
# 214      reopened       NaN  defect   Medium  Tor: 0.4.3.x-final
# 222           new       NaN  defect   Medium  Tor: 0.4.3.x-final
# 223           new       NaN  defect   Medium  Tor: 0.4.3.x-final
# 224           new       NaN  defect   Medium  Tor: 0.4.3.x-final
# 225           new       NaN  defect   Medium  Tor: 0.4.3.x-final
# 226      assigned     nickm  defect   Medium  Tor: 0.4.3.x-final
# 227  needs_review      teor  defect   Medium  Tor: 0.4.3.x-final
# 228      assigned     nickm  defect   Medium  Tor: 0.4.3.x-final
#
#         Component  Actual Points Parent ID  Points
# 202  Core Tor/Tor            NaN       NaN     5.0
# 203  Core Tor/Tor            NaN       NaN     5.0
# 214  Core Tor/Tor            NaN    #29211     NaN
# 222  Core Tor/Tor            NaN    #29215     NaN
# 223  Core Tor/Tor            NaN    #29215     NaN
# 224  Core Tor/Tor            NaN    #29215     NaN
# 225  Core Tor/Tor            NaN    #29215     NaN
# 226  Core Tor/Tor            NaN    #29215     NaN
# 227  Core Tor/Tor            4.8    #31851     0.5
# 228  Core Tor/Tor            NaN    #29211     0.5

# %%
# how many sponsor31-must tickets are already done and how many still need to be finish
csv_file.query('Sponsor=="Sponsor31-must"')['Status'].value_counts()
# Out:
# closed          18
# new              4
# assigned         2
# accepted         2
# needs_review     1
# reopened         1
# Name: Status, dtype: int64

# %%
# what about the 'could be done' tickets
csv_file.query('Sponsor=="Sponsor31-can"')['Status'].value_counts().plot.barh()

# %%
# are all of the open tickets estimated?
csv_file[csv_file.Points.isnull()].query('Status!="closed"')
# Out:
#         id                                            Summary         Sponsor  \
# 3    28208  Run bridges+hs-v23 for make test-network in 0....   Sponsor31-can
# 4    28377    Add libnss to the travis apt and macOS packages   Sponsor31-can
# 5    28378  Add libsystemd-devel to the travis config, if ...   Sponsor31-can
# 29   29689  Make Tor's test-network.sh consistent with chu...   Sponsor31-can
# 35   29821  Make circuit/channel padding correctly respect...   Sponsor31-can
# 62   30243  Stem's tests use fixed ports for tor, which ma...   Sponsor31-can
# 63   30257  Propagate USR1 and ABRT signals from stem test...   Sponsor31-can
# 81   30651  Make stem's Travis jobs log controller message...   Sponsor31-can
# 89   30720  Use test-network.sh for the examples in Chutne...   Sponsor31-can
# 109  30890         Make a useful .gitlab-ci.yml mirroring job   Sponsor31-can
# 117  30991  Auto-tabify makefiles? complain about mistabbe...   Sponsor31-can
# 145  31502  Revise authority and fallback code so that the...   Sponsor31-can
# 149  31530   Shall we require STMT_BEGIN/STMT_END everywhere?   Sponsor31-can
# 157  31631  Write a test for round-trip encode/decode oper...   Sponsor31-can
# 162  31713  Automatically run the autostyle scripts before...   Sponsor31-can
# 163  31757  test_parseconf.sh: apparently not reliable on ...   Sponsor31-can
# 165  31770      Divide connection_edge.c into separate files.   Sponsor31-can
# 170  31850  Integrate tor-guts Makefile into tor's build p...   Sponsor31-can
# 172  31869             Run doctest on all of our python files   Sponsor31-can
# 173  31891  make autostyle doesn't work when building outs...   Sponsor31-can
# 176  31909      Write a stem test to detect #31495 regression   Sponsor31-can
# 189  32163  Stop using HAVE_MODULE_{DIRAUTH,RELAY} inside ...   Sponsor31-can
# 197  32306  check-local target to enforce doxygen-correctness   Sponsor31-can
# 199  32319  Macros and definitions for declaring per-modul...   Sponsor31-can
# 214  31509        config refactor: make test-stem should pass  Sponsor31-must
# 222  32206  write high-level outline of target modular tor...  Sponsor31-must
# 223  32207          write description of pub-sub architecture  Sponsor31-must
# 224  32208  write description of control subsystem archite...  Sponsor31-must
# 225  32209  write description of config subsystem architec...  Sponsor31-must
# 226  32211  write description of subsystem initialization/...  Sponsor31-must
#
#              Status   Owner         Type Priority           Milestone  \
# 3          assigned     NaN       defect   Medium    Tor: unspecified
# 4          assigned     NaN       defect   Medium    Tor: unspecified
# 5          assigned     NaN       defect   Medium    Tor: unspecified
# 29         assigned     NaN       defect   Medium    Tor: unspecified
# 35              new     NaN       defect      Low    Tor: unspecified
# 62              new  atagar       defect   Medium                 NaN
# 63              new  atagar       defect   Medium  Tor: 0.2.9.x-final
# 81         assigned     NaN  enhancement   Medium                 NaN
# 89         assigned     NaN       defect     High                 NaN
# 109             new     NaN       defect   Medium    Tor: unspecified
# 117             new     NaN  enhancement      Low  Tor: 0.4.2.x-final
# 145             new     NaN       defect   Medium    Tor: unspecified
# 149             new     NaN  enhancement   Medium    Tor: unspecified
# 157        accepted   nickm  enhancement   Medium    Tor: unspecified
# 162             new     NaN  enhancement   Medium    Tor: unspecified
# 163        assigned     ahf       defect     High  Tor: 0.4.2.x-final
# 165        assigned   nickm         task   Medium  Tor: 0.4.2.x-final
# 170             new     NaN       defect   Medium  Tor: 0.4.3.x-final
# 172             new     NaN         task   Medium  Tor: 0.4.2.x-final
# 173             new     NaN       defect   Medium  Tor: 0.4.3.x-final
# 176    needs_review   nickm       defect   Medium  Tor: 0.4.2.x-final
# 189             new     NaN       defect   Medium  Tor: 0.4.3.x-final
# 197        assigned   nickm       defect   Medium  Tor: 0.4.3.x-final
# 199  needs_revision   nickm       defect   Medium  Tor: 0.4.3.x-final
# 214        reopened     NaN       defect   Medium  Tor: 0.4.3.x-final
# 222             new     NaN       defect   Medium  Tor: 0.4.3.x-final
# 223             new     NaN       defect   Medium  Tor: 0.4.3.x-final
# 224             new     NaN       defect   Medium  Tor: 0.4.3.x-final
# 225             new     NaN       defect   Medium  Tor: 0.4.3.x-final
# 226        assigned   nickm       defect   Medium  Tor: 0.4.3.x-final
#
#             Component  Actual Points Parent ID  Points
# 3        Core Tor/Tor            NaN    #29267     NaN
# 4        Core Tor/Tor            NaN       NaN     NaN
# 5        Core Tor/Tor            NaN    #28113     NaN
# 29       Core Tor/Tor            NaN    #29267     NaN
# 35       Core Tor/Tor            NaN       NaN     NaN
# 62      Core Tor/Stem            NaN    #29437     NaN
# 63      Core Tor/Stem            NaN    #29437     NaN
# 81      Core Tor/Stem            NaN    #28170     NaN
# 89   Core Tor/Chutney            NaN    #29267     NaN
# 109      Core Tor/Tor            NaN       NaN     NaN
# 117      Core Tor/Tor            NaN    #31713     NaN
# 145      Core Tor/Tor            NaN    #29211     NaN
# 149      Core Tor/Tor            0.1       NaN     NaN
# 157      Core Tor/Tor            NaN    #29211     NaN
# 162      Core Tor/Tor            NaN    #29226     NaN
# 163      Core Tor/Tor            NaN       NaN     NaN
# 165      Core Tor/Tor            NaN       NaN     NaN
# 170      Core Tor/Tor            NaN    #29214     NaN
# 172      Core Tor/Tor            NaN       NaN     NaN
# 173      Core Tor/Tor            NaN    #31713     NaN
# 176     Core Tor/Stem            NaN       NaN     NaN
# 189      Core Tor/Tor            NaN    #31851     NaN
# 197      Core Tor/Tor            NaN    #29214     NaN
# 199      Core Tor/Tor            0.2    #29211     NaN
# 214      Core Tor/Tor            NaN    #29211     NaN
# 222      Core Tor/Tor            NaN    #29215     NaN
# 223      Core Tor/Tor            NaN    #29215     NaN
# 224      Core Tor/Tor            NaN    #29215     NaN
# 225      Core Tor/Tor            NaN    #29215     NaN
# 226      Core Tor/Tor            NaN    #29215     NaN

# %%
# which ones are the big tickets?
open_tickets.query('Points>6')
# Out:
#         id                                            Summary        Sponsor  \
# 8    29209      Reduce visibility of more data type internals  Sponsor31-can
# 9    29210  Distribute control.c functionality across vari...  Sponsor31-can
# 10   29211  Distribute config.c functionality across more ...  Sponsor31-can
# 11   29212             Create more modularity inside src/core  Sponsor31-can
# 12   29213  Minimize the boundary between src/core and src...  Sponsor31-can
# 19   29222    Fix biggest violations of coding best-practices  Sponsor31-can
# 22   29225  Improve efficiency and flexibility of threadpo...  Sponsor31-can
# 24   29227  Audit Tor roles (relay, bridge, etc) and remov...  Sponsor31-can
# 25   29228  Unify some or all of Tor's various message/eve...  Sponsor31-can
# 121  31121        Use publish-subscribe system in more places  Sponsor31-can
# 122  31122         Use subsystems architecture in more places  Sponsor31-can
# 127  31179            Eliminate non tor_queue.h linked lists.  Sponsor31-can
# 130  31182                Add more typesafe containers to tor  Sponsor31-can
# 132  31238         Write a nontrivial "preferred" rust module  Sponsor31-can
#
#        Status     Owner         Type Priority           Milestone  \
# 8         new       NaN         task   Medium  Tor: 0.4.3.x-final
# 9         new  catalyst         task   Medium  Tor: 0.4.3.x-final
# 10   assigned     nickm         task   Medium  Tor: 0.4.3.x-final
# 11        new       NaN         task   Medium  Tor: 0.4.3.x-final
# 12        new       NaN  enhancement   Medium  Tor: 0.4.3.x-final
# 19        new       NaN         task   Medium    Tor: unspecified
# 22        new       NaN         task   Medium  Tor: 0.4.3.x-final
# 24        new       NaN  enhancement   Medium  Tor: 0.4.3.x-final
# 25        new       NaN         task   Medium  Tor: 0.4.3.x-final
# 121       new       NaN  enhancement   Medium    Tor: unspecified
# 122       new       NaN  enhancement   Medium  Tor: 0.4.3.x-final
# 127       new       NaN         task   Medium                 NaN
# 130       new       NaN         task   Medium  Tor: 0.4.3.x-final
# 132       new       NaN  enhancement   Medium  Tor: 0.4.3.x-final
#
#         Component  Actual Points Parent ID  Points
# 8    Core Tor/Tor            3.5       NaN    15.0
# 9    Core Tor/Tor            NaN       NaN    23.0
# 10   Core Tor/Tor            NaN       NaN    23.0
# 11   Core Tor/Tor            NaN       NaN    15.0
# 12   Core Tor/Tor            NaN       NaN    15.0
# 19   Core Tor/Tor            NaN       NaN    10.0
# 22   Core Tor/Tor            NaN       NaN    15.0
# 24   Core Tor/Tor            NaN       NaN    15.0
# 25   Core Tor/Tor            NaN       NaN    10.0
# 121  Core Tor/Tor            NaN       NaN    20.0
# 122  Core Tor/Tor            NaN       NaN    20.0
# 127  Core Tor/Tor            NaN       NaN     8.0
# 130  Core Tor/Tor            NaN       NaN    20.0
# 132  Core Tor/Tor            NaN       NaN     8.0

# %%
# how many points still need to be done
points_to_go = open_tickets.filter(['Points']).sum()

points_to_go/3  # thinking 3 days per week for 1 developer

# starting June: we have until december:  24 semanas  
# ---> We will need at least 2.5 developers to complete 48 weeks of tickets in this sponsor
# ---> There are -12 points
# Out:
# Points    100.466667
# dtype: float64

# %%
# how long the review tickets have been last modified
open_tickets.query('Status=="needs_review"').filter(['id', 'Summary','Modified', 'Owner', 'Reviewer'])
# Out:
#         id                                            Summary  Owner
# 105  30866  Teach config.c to work with options configured...  nickm
# 176  31909      Write a stem test to detect #31495 regression  nickm
# 200  32339  Use a table to drive options_check_transition ...    NaN
# 227  32213  Phase 1: Disable minimal dirauth and relay opt...   teor
