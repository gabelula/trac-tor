# %%
# All tickets until June 24th, 2019

csv_path='/Users/gaba/Code/torproject/trac/datasets/all_tickets.csv'

import pandas as pd
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np

csv_file = pd.read_csv(csv_path)

# %%
# which sponsors got ticket closed
sponsors_by_tickets = csv_file['Sponsor'].value_counts()

objects = tuple(sponsors_by_tickets.keys())
y_pos = np.arange(len(objects))
tickets = list(sponsors_by_tickets)

plt.barh(y_pos, tickets, align='center', alpha=0.5)
plt.yticks(y_pos, objects, fontsize='xx-small')
plt.xlabel('number of tickets')
plt.title('Tickets by Sponsor')

plt.show()

# %%
# who had tickets
csv_file['Owner'].value_counts()
# Out:
# tbb-team                 4136
# nickm                    1210
# mikeperry                1024
# pde                       796
# erinn                     724
# atagar                    660
# metrics-team              621
# hellais                   548
# phobos                    524
# karsten                   442
# teor                      439
# tpa                       437
# hiro                      405
# chiiph                    375
# dgoulet                   333
# isis                      323
# asn                       322
# n8fr8                     244
# qbi                       236
# dcf                       233
# irl                       231
# runa                      222
# boklm                     222
# zyan                      211
# Sebastian                 207
# ioerror                   204
# tor-gitadm                179
# weasel                    165
# brade                     165
# yawning                   161
#                          ...
# hellais, naif               1
# attila                      1
# Ulincsys                    1
# intgr                       1
# brade, phoul                1
# micah                       1
# ancrypt                     1
# chiiph, malaparte_          1
# aquintex                    1
# tcz001                      1
# JeremyRand                  1
# cwacek                      1
# < mrphs >                   1
# nito                        1
# felixious                   1
# kelley                      1
# neillm                      1
# ilv, mrphs, sukhbir         1
# Cornax                      1
# pranavrc                    1
# None yet, but hopeful       1
# dave2008                    1
# Larrykl77590                1
# Backxwash                   1
# ashishnitinpatil            1
# <  >                        1
# WolfCyber                   1
# angelo620                   1
# samori65                    1
# koolfy                      1
# Name: Owner, Length: 339, dtype: int64

# %%
# What type of tickets we got
csv_file['Type'].value_counts().plot.barh()

# %%
# How many high and very high tickets
csv_file['Priority'].value_counts().plot.barh()

# %%
# which milestone the tickets were for
csv_file['Milestone'].value_counts()
# Out:
# Tor: unspecified                    2498
# Tor: 0.2.3.x-final                   472
# Tor: 0.2.4.x-final                   447
# Tor: 0.3.5.x-final                   383
# Tor: 0.2.9.x-final                   382
# Tor: 0.3.2.x-final                   360
# Tor: 0.2.8.x-final                   353
# Tor: 0.2.5.x-final                   319
# Tor: 0.2.6.x-final                   306
# Tor: 0.2.2.x-final                   306
# Tor: 0.3.3.x-final                   271
# Tor: 0.3.4.x-final                   264
# Tor: 0.2.7.x-final                   248
# Tor: 0.3.0.x-final                   237
# Tor: 0.3.1.x-final                   234
# Tor: 0.4.0.x-final                   207
# Tor: 0.4.1.x-final                   206
# Tor: 0.4.2.x-final                   126
# sbws: 1.0.x-final                    114
# TorBrowserBundle 2.2.x-stable         96
# TorBrowserBundle 2.3.x-stable         90
# website redesign                      78
# sbws: unspecified                     62
# HTTPS-E next Firefox dev release      50
# sbws: 1.1.x-final                     46
# Vidalia: 0.3.x                        45
# WebsiteV3                             39
# Tor: very long term                   33
# sbws: 1.2.x-final                     33
# Deliverable-Sep2010                   32
#                                     ...
# 0.1.0.6-rc                             2
# ExoneraTor 1.0.0                       2
# Onionoo 1.14.0                         2
# ExoneraTor 2.1.0                       2
# 0.2.1.22                               2
# metrics-lib 1.8.0                      2
# CollecTor 1.1.1                        2
# Android (Orbot): 1.0                   1
# 1.1                                    1
# HTTPS-E 3.2.1                          1
# CollecTor 1.1.2                        1
# 1.2                                    1
# CollecTor 1.4.0                        1
# 0.1.1.1-alpha                          1
# 0.1.2.15                               1
# CollecTor 2.0.0                        1
# 0.1.0.2-rc                             1
# sbws: 2.0.x-final                      1
# 0.2.0.8-alpha                          1
# 0.1.2.20                               1
# 0.2.1.11-alpha                         1
# Chronos: phase one                     1
# Metrics 2.0.0                          1
# 0.2.2.6-alpha                          1
# 0.0.9.7                                1
# 0.1.1.13-alpha                         1
# Onionoo-1.5.0                          1
# ttdnsd: 0.8                            1
# Onionoo-1.9.0                          1
# 0.2.0.33                               1
# Name: Milestone, Length: 145, dtype: int64

# %%
# How many 'big' tickets got resolved
csv_file['Points'].value_counts()
# Out:
# 0.1     27
# 1.0     16
# 0.2     12
# 0.5      9
# 0.0      6
# 3.0      4
# 0.3      2
# 15.0     2
# 2.0      2
# 10.0     2
# Name: Points, dtype: int64

# %%
# How tickets got resolved
csv_file['Resolution'].value_counts()
# Out:
# fixed               12473
# implemented          2476
# wontfix              2212
# duplicate            2048
# not a bug             964
# worksforme            804
# invalid               801
# Fixed                 627
# user disappeared      368
# Not a bug             115
# Duplicate              84
# Implemented            81
# Works for me           46
# User disappeared       38
# None                   31
# Won't fix              23
# Deferred               22
# Won't implement        19
# Name: Resolution, dtype: int64

# %%
# How many days took to complete the ticket versus estimation
csv_file.filter(items=['Sponsor', 'Points', 'Actual Points']).groupby('Sponsor') #.sum().plot.barh()

# %%
# How much work was not sponsored

sponsor_and_not = csv_file['Sponsor'].notnull().value_counts().rename(lambda x: 'Sponsored' if x else 'Not Sponsored')

sponsor_and_not.plot.barh()

# %%
# From all not sponsored work which releases they went into

not_sponsored_work = csv_file[csv_file.Sponsor.isnull()]
not_sponsored_work['Milestone'].value_counts()
# Out:
# Tor: unspecified                    2229
# Tor: 0.2.3.x-final                   472
# Tor: 0.2.4.x-final                   446
# Tor: 0.3.5.x-final                   319
# Tor: 0.2.5.x-final                   317
# Tor: 0.2.2.x-final                   306
# Tor: 0.3.2.x-final                   294
# Tor: 0.2.6.x-final                   292
# Tor: 0.2.9.x-final                   287
# Tor: 0.2.8.x-final                   278
# Tor: 0.3.3.x-final                   219
# Tor: 0.2.7.x-final                   214
# Tor: 0.3.4.x-final                   182
# Tor: 0.3.0.x-final                   169
# Tor: 0.3.1.x-final                   160
# Tor: 0.4.1.x-final                   128
# Tor: 0.4.0.x-final                   121
# sbws: 1.0.x-final                    114
# TorBrowserBundle 2.2.x-stable         96
# TorBrowserBundle 2.3.x-stable         90
# website redesign                      70
# sbws: unspecified                     62
# Tor: 0.4.2.x-final                    56
# HTTPS-E next Firefox dev release      50
# sbws: 1.1.x-final                     45
# Vidalia: 0.3.x                        44
# WebsiteV3                             39
# sbws: 1.2.x-final                     33
# Tor: very long term                   32
# Deliverable-Sep2010                   32
#                                     ...
# 0.1.0.6-rc                             2
# ExoneraTor 1.0.0                       2
# Onionoo 1.14.0                         2
# ExoneraTor 2.1.0                       2
# 0.2.1.22                               2
# metrics-lib 1.8.0                      2
# CollecTor 1.1.1                        2
# Android (Orbot): 1.0                   1
# 1.1                                    1
# HTTPS-E 3.2.1                          1
# CollecTor 1.1.2                        1
# 1.2                                    1
# CollecTor 1.4.0                        1
# 0.1.1.1-alpha                          1
# 0.1.2.15                               1
# CollecTor 2.0.0                        1
# 0.1.0.2-rc                             1
# sbws: 2.0.x-final                      1
# 0.2.0.8-alpha                          1
# 0.1.2.20                               1
# 0.2.1.11-alpha                         1
# Chronos: phase one                     1
# Metrics 2.0.0                          1
# 0.2.2.6-alpha                          1
# 0.0.9.7                                1
# 0.1.1.13-alpha                         1
# Onionoo-1.5.0                          1
# ttdnsd: 0.8                            1
# Onionoo-1.9.0                          1
# 0.2.0.33                               1
# Name: Milestone, Length: 145, dtype: int64

# %%
# What is this non sponsored work

not_sponsored_work['Type'].value_counts().plot.barh()

# %%
# We understnd bugs and want to track which specific non sponsored enhancement we are prioritizing. 
not_sponsored_work.query('Type=="enhancement"')

# It seems that this are all tickets that were: 
# . closed some time ago but just recently commented.
# . tickets that volunteers worked on
# . updates to scripts (like #30114)
# Out:
#           id                                            Summary  \
# 13      2561                       Context based rule interface
# 14      2562                       Context based rule interface
# 57      5592                   can't connect to .onion services
# 63      5997  ML privacy enhancement: remove incoming mail p...
# 75      6541  Make Decentralized SSL Observatory / Tor inter...
# 81      6958                    Implement JavaScript HTTP proxy
# 89      8294                   take at least a five day weekend
# 98      9380   BridgeDB should use Stem for parsing descriptors
# 130    12872      Know within which country a bridge is located
# 135    13578  Store Pluggable Transport information in database
# 170    18071        Add new obfs4 bridge riemann to Tor Browser
# 171    18104  Add new default obfs4 bridge noether to Tor Br...
# 194    21961  should torbrowser enable network.IDN_show_puny...
# 197    22545  .onion sites are being labled with "insecure c...
# 262    29116  I need help.. all I know is I accidentally cha...
# 277    29810                         Pornhub login doesn't work
# 282    30099                           Orbot: v3 onion services
# 327      591  What is the control password in the last Alpha...
# 334      716       Mixminion Executable (Mixminion.exe) Please!
# 347     1110         Popup box asking about language preference
# 391     2697  Detect exit nodes running 'transparent' HTTP p...
# 400     2843     Check an environment variable for a SOCKS port
# 428     3446                               Support Firefox 5.0.
# 479     5863             Remove the ability to toggle Torbutton
# 497     6521                          air gap the build machine
# 511     7045                Get redirectTo API merged into FF17
# 536     8228  Tor Launcher: Ensure we always have a Tor on 1...
# 547     8472  Check goes down, TBB appears to be failing to ...
# 556     8613  Complete the oonib scripts for publishing reports
# 567     8927  Please build future TBB versions with optimiza...
# ...      ...                                                ...
# 28879  19052                      collector jenkins integration
# 28882  19562        Implement a voting_schedule_free() function
# 28884  19774         bridges.torproject.org could use a favicon
# 28886  20010    modifications of relay(s) on fallback whitelist
# 28888  20168  Clarify our #if{n}def by commenting what they ...
# 28891  20268  Usuability of right-click search for startpage...
# 28900  21148  Restore documentation for the approved-routers...
# 28901  21159                      Superfluous Include Statement
# 28903  21250        Suggestions for translations source strings
# 28904  21281           Allow process poll rate to be customized
# 28905  21284       Add torrc option for non-anonymous SocksPort
# 28912  21994  Consensus Health: what is the distribution of ...
# 28914  22240      Selectively re-enable extension auto updates.
# 28919  22524                             clear download history
# 28921  22828  UX: RSS Feed "Edit as new Message" has still H...
# 28924  23207  Registration on trac seems to be counterintuitive
# 28925  23282  Add option to permanently block resizes of the...
# 28928  23924                           Improve control-spec.txt
# 28929  23939  Create an XMPP interface for querying relay/br...
# 28930  24134     Make supported version timeline easier to find
# 28933  24463  Advanced search: Add a client auto-completion ...
# 28939  25188  Spec bug in formal definition of Document in d...
# 28950  26420  Testing - specify literal patterns instead of ...
# 28951  26492  code style improvements for src/rust/protover/...
# 28959  28965                   Please accept -i :9150 parameter
# 28960  28999                    Mention dependencies in INSTALL
# 28961  29000             Let torsocks run from source directory
# 28962  29254                  open multiple urls on commandline
# 28968  30094                 MAPADDRESS exitnode by CountryCode
# 28970  30299                           Switch network interface
#
#                   Status         Owner         Type   Priority  \
# 13                closed           NaN  enhancement  Immediate
# 14                closed           pde  enhancement  Immediate
# 57                closed           NaN  enhancement  Immediate
# 63                closed       rransom  enhancement  Immediate
# 75                closed     mikeperry  enhancement  Immediate
# 81                closed       ioerror  enhancement  Immediate
# 89                closed       hellais  enhancement  Immediate
# 98                closed          isis  enhancement  Immediate
# 130               closed          isis  enhancement  Immediate
# 135               closed          isis  enhancement  Immediate
# 170               closed      tbb-team  enhancement  Immediate
# 171               closed          isis  enhancement  Immediate
# 194         needs_review      tbb-team  enhancement  Immediate
# 197               closed      tbb-team  enhancement  Immediate
# 262               closed           NaN  enhancement  Immediate
# 277               closed           NaN  enhancement  Immediate
# 282                  new         n8fr8  enhancement  Immediate
# 327               closed           NaN  enhancement  Very High
# 334               closed           NaN  enhancement  Very High
# 347               closed     mikeperry  enhancement  Very High
# 391               closed     mikeperry  enhancement  Very High
# 400               closed     mikeperry  enhancement  Very High
# 428               closed     mikeperry  enhancement  Very High
# 479               closed     mikeperry  enhancement  Very High
# 497               closed           NaN  enhancement  Very High
# 511               closed     mikeperry  enhancement  Very High
# 536    needs_information         brade  enhancement  Very High
# 547               closed     mikeperry  enhancement  Very High
# 556               closed        aagbsn  enhancement  Very High
# 567               closed      tbb-team  enhancement  Very High
# ...                  ...           ...          ...        ...
# 28879             closed           NaN  enhancement   Very Low
# 28882             closed           NaN  enhancement   Very Low
# 28884           assigned      antonela  enhancement   Very Low
# 28886             closed          teor  enhancement   Very Low
# 28888             closed           cjb  enhancement   Very Low
# 28891             closed      tbb-team  enhancement   Very Low
# 28900             closed           NaN  enhancement   Very Low
# 28901             closed           NaN  enhancement   Very Low
# 28903             closed      emmapeel  enhancement   Very Low
# 28904                new           NaN  enhancement   Very Low
# 28905                new           NaN  enhancement   Very Low
# 28912                new           tom  enhancement   Very Low
# 28914             closed       yawning  enhancement   Very Low
# 28919                new       sukhbir  enhancement   Very Low
# 28921                new       sukhbir  enhancement   Very Low
# 28924             closed           qbi  enhancement   Very Low
# 28925             closed      tbb-team  enhancement   Very Low
# 28928             closed           NaN  enhancement   Very Low
# 28929           assigned  metrics-team  enhancement   Very Low
# 28930             closed       dgoulet  enhancement   Very Low
# 28933                new  metrics-team  enhancement   Very Low
# 28939             closed           NaN  enhancement   Very Low
# 28950             closed           dmr  enhancement   Very Low
# 28951             closed           NaN  enhancement   Very Low
# 28959             closed        atagar  enhancement   Very Low
# 28960           assigned           NaN  enhancement   Very Low
# 28961           assigned           NaN  enhancement   Very Low
# 28962             closed      tbb-team  enhancement   Very Low
# 28968                new           NaN  enhancement   Very Low
# 28970                new           NaN  enhancement   Very Low
#
#                            Milestone                              Component  \
# 13                               NaN                   - Select a component
# 14                               NaN  HTTPS Everywhere/EFF-HTTPS Everywhere
# 57                               NaN                   - Select a component
# 63                               NaN    Internal Services/Tor Sysadmin Team
# 75                               NaN  HTTPS Everywhere/EFF-HTTPS Everywhere
# 81                               NaN                  Applications/TorBirdy
# 89                               NaN                   - Select a component
# 98                               NaN                 Circumvention/BridgeDB
# 130                              NaN                 Circumvention/BridgeDB
# 135                              NaN                 Circumvention/BridgeDB
# 170                              NaN               Applications/Tor Browser
# 171                              NaN               Applications/Tor Browser
# 194                              NaN               Applications/Tor Browser
# 197                              NaN               Applications/Tor Browser
# 262                              NaN                               Core Tor
# 277                              NaN                               Webpages
# 282                              NaN                     Applications/Orbot
# 327                              NaN                           Core Tor/Tor
# 334                              NaN                        Mixminion-Other
# 347                              NaN                 Applications/Torbutton
# 391                              NaN                       Core Tor/Torflow
# 400    TorBrowserBundle 2.2.x-stable                       TorBrowserButton
# 428                              NaN                 Applications/Torbutton
# 479                              NaN                 Applications/Torbutton
# 497                              NaN                        Archived/Ponies
# 511                              NaN                   Firefox Patch Issues
# 536                              NaN              Applications/Tor Launcher
# 547                              NaN  Applications/Tor bundles/installation
# 556                              NaN                          Archived/Ooni
# 567                              NaN               Applications/Tor Browser
# ...                              ...                                    ...
# 28879                            NaN                      Metrics/CollecTor
# 28882             Tor: 0.2.9.x-final                           Core Tor/Tor
# 28884                            NaN                 Circumvention/BridgeDB
# 28886             Tor: 0.2.9.x-final              Core Tor/Fallback Scripts
# 28888             Tor: 0.3.2.x-final                           Core Tor/Tor
# 28891                            NaN               Applications/Tor Browser
# 28900             Tor: 0.3.2.x-final                           Core Tor/Tor
# 28901                            NaN                           Core Tor/Tor
# 28903                            NaN                 Community/Translations
# 28904               Tor: unspecified                           Core Tor/Tor
# 28905               Tor: unspecified                           Core Tor/Tor
# 28912                            NaN               Metrics/Consensus Health
# 28914                            NaN           Archived/Tor Browser Sandbox
# 28919                            NaN                  Applications/TorBirdy
# 28921                            NaN                  Applications/TorBirdy
# 28924                            NaN       Internal Services/Service - trac
# 28925                            NaN               Applications/Tor Browser
# 28928             Tor: 0.3.3.x-final                           Core Tor/Tor
# 28929                            NaN                            Metrics/Bot
# 28930             Tor: 0.3.2.x-final                           Core Tor/Tor
# 28933                            NaN                   Metrics/Relay Search
# 28939             Tor: 0.3.4.x-final                           Core Tor/Tor
# 28950                            NaN                          Core Tor/Stem
# 194             NaN    NaN       NaN     NaN       cypherpunks
# 197             NaN    NaN       NaN     NaN             mrphs
# 262             NaN    NaN       NaN     NaN            micc2x
# 277             NaN    NaN       NaN     NaN          unfcktor
# 282             NaN    NaN       NaN     NaN       cypherpunks
# 327             NaN    NaN       NaN     NaN      King_Alexius
# 334             NaN    NaN       NaN     NaN  computerguy12056
# 347               2      2       NaN     NaN              arma
# 391               1      1       NaN     NaN           rransom
# 400               2      2       NaN     NaN         mikeperry
# 428               1      3       NaN     NaN         mikeperry
# 479               1      1       NaN     NaN         mikeperry
# 497             NaN    NaN       NaN     NaN       cypherpunks
# 511               2    NaN       NaN     NaN         mikeperry
# 536             NaN    NaN       NaN     NaN           ioerror
# 547             NaN    NaN       NaN     NaN           ioerror
# 556             NaN    NaN       NaN     NaN           hellais
# 567             NaN    NaN       NaN     NaN       cypherpunks
# ...             ...    ...       ...     ...               ...
# 28879           NaN    NaN       NaN     NaN            iwakeh
# 28882           NaN    0.1   dgoulet     NaN           dgoulet
# 28884           NaN      1       NaN     NaN              isis
# 28886           0.2    NaN       NaN     NaN              niij
# 28888            .1    NaN   dgoulet     NaN           dgoulet
# 28891           NaN    NaN       NaN     NaN       cypherpunks
# 28900           NaN     .1       NaN     NaN               ln5
# 28901           NaN    NaN       NaN     NaN    BenjaminPollak
# 28903           NaN    NaN       NaN     NaN     scootergrisen
# 28904           NaN    NaN       NaN     NaN            atagar
# 28905           NaN      1       NaN     NaN              teor
# 28912           NaN    NaN       NaN     NaN              teor
# 28914           NaN    NaN       NaN     NaN           yawning
# 28919           NaN    NaN       NaN     NaN       cypherpunks
# 28921           NaN    NaN       NaN     NaN       cypherpunks
# 28924           NaN    NaN       NaN     NaN      mail@5ece.de
# 28925           NaN    NaN       NaN     NaN       cypherpunks
# 28928           NaN    NaN       NaN     NaN               tom
# 28929           NaN      3       NaN     NaN               irl
# 28930           NaN    NaN       NaN     NaN               tom
# 28933           NaN    NaN       NaN     NaN       cypherpunks
# 28939           NaN    0.1     nickm     NaN       witchof0x20
# 28950           NaN    NaN    atagar     NaN               dmr
# 28951           NaN    NaN  catalyst     NaN          frewsxcv
# 28959           NaN    NaN       NaN     NaN       traumschule
# 28960           NaN    NaN       NaN     NaN       traumschule
# 28961           NaN    NaN       NaN     NaN       traumschule
# 28962           NaN    NaN       NaN     NaN      themusicgod1
# 28968           NaN    NaN       NaN     NaN       cypherpunks
# 28970           NaN    NaN       NaN     NaN       enriquejr99
#
# [5711 rows x 17 columns]

# %%
# What are the not sponsored bugs fixed?
not_sponsored_work.query('Type=="defect"')['Severity'].value_counts().plot.barh()

# %%
not_sponsored_work.query('Type=="defect"').query('Severity=="Minor"')
# Out:
#           id                                            Summary  \
# 1732    3667                   Toolbar icons non-deterministic?
# 3090   17398            Memory leak in batch signature checking
# 3161   18254  option to disable a security prompt when it po...
# 3251   19424  remove hard coded paths and set default proper...
# 4281   30134  reEnable IPv6 routing by Orbot add back Route ...
# 10873  10573  `nsILocalFile` should be replaced with `nsIFil...
# 14360  16182  Replacing an older pending vote from this dire...
# 15159  17347                  Tor doesn't build under musl-libc
# 15161  17351  Remove unused code / entities related to "fix_...
# 15188  17392            tor manpage should link to torspec repo
# 15288  17517  Consider using different color for "Add Except...
# 15334  17575            Openstreetmap GUI elements not rendered
# 15433  17724                   Unreliable rend_cache_purge test
# 15439  17732              Document required build tool versions
# 15455  17751  Use router_get_my_routerinfo() rather than des...
# 15472  17778                           Memory leak in ntor test
# 15508  17828  no traffic graph for 3 days and for one weeks ...
# 15666  18074                          TBB Vagrantfile uses HTTP
# 15683  18095  Unit test integer precision warnings on 32 bit...
# 15802  18263    GETCONF provides incorrect value when undefined
# 15813  18277   Tor was unable to provide the descriptor for ...
# 15877  18368    Don't call a consensus a "vote" in log messages
# 15882  18373              Trunnel can generate memcpy(p,NULL,0)
# 15902  18404           "make test-network" failed for test010bc
# 15906  18448  transproxy enabled on FreeBSD but not derivatives
# 15909  18451               log msg is printed twice after 5 sec
# 15952  18510  "AccountingMax 20 TB" doubles the actual netwo...
# 15972  18543  Change dialog message when there is no protoco...
# 16003  18590  "My reported tickets" doesn't work like "my ti...
# 16012  18600  Warning in rend_service_intro_has_opened isn't...
# ...      ...                                                ...
# 28378  28956                              Github nyx repository
# 28390  29164  with dark desktop theme: unreadable guard text...
# 28405  29621               Systemd Tor service starts too early
# 28409  29674                      silence or uninstall logwatch
# 28412  29712  sbws should use 1024 to convert kilobytes to b...
# 28413  29741  Work out how to fail chutney travis jobs when ...
# 28418  29846         fstrim script makes noises on some servers
# 28420  29870      Tor Browser hotkeys stop working unexpectedly
# 28435  30416                         Enforce cooperation sanity
# 28436  30422  test.integ.control.controller failing for tor 2.x
# 28437  30453                         Failing tests on travis ci
# 28442  30561  Fixed tor_vasprintf on systems without vasprintf.
# 28446  30723  Work out why no measurements are excluded beca...
# 28447  30724  Work out why relay_in_recent_consensus_count i...
# 28450  30858  Load geoip and geoip6 files during the unit tests
# 28451  30920     Detect uint64 overflow in config_parse_units()
# 28784  14828  Multiple hidden services can share a pk_digest...
# 28841  17602         'HidServDirectoryV2 0' not disabling HSDir
# 28845  17671  TorperfResultImpl doesn't set its @type annota...
# 28849  17846  32bit decimal IP address fail (i.e. no octets)...
# 28861  18182      Windows: Tor Browser Bundle vs Tor NT Service
# 28883  19733  GETINFO response parser doesn't handle AF_UNIX...
# 28885  19777  tor-gencert should warn nicely when PEM passph...
# 28899  20883  Ignore relays without contact info when emaili...
# 28920  22534  Stop parsing rend protocol versions greater th...
# 28935  24630  Stop initialising rust git submodules, travis ...
# 28937  24923               typo in Nyx docs config page heading
# 28964  29499  permission error: nyx requires executable perm...
# 28966  30084  Relay: channel_tls_process_netinfo_cell privat...
# 28967  30085  Bug: Unexpectedly high use successes counts (1...
#
#                   Status      Owner    Type  Priority           Milestone  \
# 1732   needs_information   tbb-team  defect      High                 NaN
# 3090              closed        NaN  defect      High  Tor: 0.2.7.x-final
# 3161              closed   tbb-team  defect      High                 NaN
# 3251              closed     iwakeh  defect      High     CollecTor 1.0.0
# 4281                 new      n8fr8  defect      High                 NaN
# 10873             closed   tbb-team  defect    Medium                 NaN
# 14360                new        NaN  defect    Medium    Tor: unspecified
# 15159             closed        NaN  defect    Medium  Tor: 0.2.7.x-final
# 15161             closed        mcs  defect    Medium                 NaN
# 15188             closed        NaN  defect    Medium  Tor: 0.2.8.x-final
# 15288             closed      huyvq  defect    Medium                 NaN
# 15334             closed   tbb-team  defect    Medium                 NaN
# 15433             closed        NaN  defect    Medium  Tor: 0.2.8.x-final
# 15439             closed        NaN  defect    Medium  Tor: 0.2.8.x-final
# 15455             closed    hkannan  defect    Medium  Tor: 0.2.9.x-final
# 15472             closed        NaN  defect    Medium  Tor: 0.2.8.x-final
# 15508             closed        phw  defect    Medium                 NaN
# 15666             closed   tbb-team  defect    Medium                 NaN
# 15683             closed        NaN  defect    Medium  Tor: 0.2.8.x-final
# 15802                new        NaN  defect    Medium    Tor: unspecified
# 15813             closed     atagar  defect    Medium                 NaN
# 15877             closed      nickm  defect    Medium  Tor: 0.2.8.x-final
# 15882             closed      nickm  defect    Medium  Tor: 0.2.8.x-final
# 15902             closed        NaN  defect    Medium                 NaN
# 15906             closed        NaN  defect    Medium  Tor: 0.2.8.x-final
# 15909                new        NaN  defect    Medium    Tor: unspecified
# 15952             closed        NaN  defect    Medium                 NaN
# 15972                new      brade  defect    Medium                 NaN
# 16003             closed  Sebastian  defect    Medium                 NaN
# 16012             closed        NaN  defect    Medium  Tor: 0.2.8.x-final
# ...                  ...        ...     ...       ...                 ...
# 28378                new       hiro  defect       Low                 NaN
# 28390                new   tbb-team  defect       Low                 NaN
# 28405                new        NaN  defect       Low                 NaN
# 28409             closed    anarcat  defect       Low                 NaN
# 28412             closed        NaN  defect       Low   sbws: 1.0.x-final
# 28413                new        NaN  defect       Low                 NaN
# 28418                new        tpa  defect       Low                 NaN
# 28420  needs_information   tbb-team  defect       Low                 NaN
# 28435                new     alison  defect       Low                 NaN
# 28436             closed     atagar  defect       Low                 NaN
# 28437             closed     atagar  defect       Low                 NaN
# 28442        merge_ready        NaN  defect       Low  Tor: 0.4.0.x-final
# 28446                new        NaN  defect       Low   sbws: 1.1.x-final
# 28447                new        NaN  defect       Low   sbws: 1.1.x-final
# 28450           assigned       teor  defect       Low    Tor: unspecified
# 28451                new        NaN  defect       Low  Tor: 0.4.2.x-final
# 28784     needs_revision       twim  defect  Very Low    Tor: unspecified
# 28841             closed        NaN  defect  Very Low  Tor: 0.2.8.x-final
# 28845             closed    karsten  defect  Very Low                 NaN
# 28849             closed        NaN  defect  Very Low                 NaN
# 28861             closed        NaN  defect  Very Low                 NaN
# 28883             closed   tbb-team  defect  Very Low                 NaN
# 28885                new        NaN  defect  Very Low    Tor: unspecified
# 28899                new        NaN  defect  Very Low                 NaN
# 28920                new        NaN  defect  Very Low    Tor: unspecified
# 28935             closed        NaN  defect  Very Low  Tor: 0.3.2.x-final
# 28937             closed     atagar  defect  Very Low                 NaN
# 28964  needs_information        NaN  defect  Very Low    Tor: unspecified
# 28966             closed        NaN  defect  Very Low    Tor: unspecified
# 28967                new        NaN  defect  Very Low    Tor: unspecified
#
#                                     Component Severity        Resolution  \
# 1732                 Applications/Tor Browser    Minor               NaN
# 3090                             Core Tor/Tor    Minor             fixed
# 3161                 Applications/Tor Browser    Minor  user disappeared
# 3251                        Metrics/CollecTor    Minor             fixed
# 4281                       Applications/Orbot    Minor               NaN
# 10873                Applications/Tor Browser    Minor             fixed
# 14360                            Core Tor/Tor    Minor               NaN
# 15159                            Core Tor/Tor    Minor             fixed
# 15161                Applications/Tor Browser    Minor             fixed
# 15188                            Core Tor/Tor    Minor       implemented
# 15288                  Archived/Tor Messenger    Minor             fixed
# 15334                Applications/Tor Browser    Minor        worksforme
# 15433                            Core Tor/Tor    Minor             fixed
# 15439                            Core Tor/Tor    Minor             fixed
# 15455                            Core Tor/Tor    Minor             fixed
# 15472                            Core Tor/Tor    Minor             fixed
# 15508                    Metrics/Relay Search    Minor         duplicate
# 15666                Applications/Tor Browser    Minor           wontfix
# 15683                            Core Tor/Tor    Minor             fixed
# 15802                            Core Tor/Tor    Minor               NaN
# 15813                           Core Tor/Stem    Minor         not a bug
# 15877                            Core Tor/Tor    Minor             fixed
# 15882                            Core Tor/Tor    Minor             fixed
# 15902                            Core Tor/Tor    Minor             fixed
# 15906                            Core Tor/Tor    Minor             fixed
# 15909                            Core Tor/Tor    Minor               NaN
# 15952                            Core Tor/Tor    Minor           invalid
# 15972               Applications/Tor Launcher    Minor               NaN
# 16003                        Webpages/Website    Minor        worksforme
# 16012                            Core Tor/Tor    Minor             fixed
# ...                                       ...      ...               ...
# 28378  Internal Services/Service - github tpo    Minor               NaN
# 28390                Applications/Tor Browser    Minor               NaN
# 28405                                Core Tor    Minor               NaN
# 28409     Internal Services/Tor Sysadmin Team    Minor             fixed
# 28412                           Core Tor/sbws    Minor         not a bug
# 28413                        Core Tor/Chutney    Minor               NaN
# 28418     Internal Services/Tor Sysadmin Team    Minor               NaN
# 28420                Applications/Tor Browser    Minor               NaN
# 28435                               Community    Minor               NaN
# 28436                           Core Tor/Stem    Minor             fixed
# 28437                           Core Tor/Stem    Minor         duplicate
# 28442                            Core Tor/Tor    Minor               NaN
# 28446                           Core Tor/sbws    Minor               NaN
# 28447                           Core Tor/sbws    Minor               NaN
# 28450                            Core Tor/Tor    Minor               NaN
# 28451                            Core Tor/Tor    Minor               NaN
# 28784                            Core Tor/Tor    Minor               NaN
# 28841                            Core Tor/Tor    Minor         not a bug
# 28845                         Metrics/Library    Minor         duplicate
# 28849                            Core Tor/Tor    Minor           invalid
# 28861                Applications/Tor Browser    Minor         duplicate
# 28883                Applications/Tor Browser    Minor             fixed
# 28885                            Core Tor/Tor    Minor               NaN
# 28899               Core Tor/Fallback Scripts    Minor               NaN
# 28920                            Core Tor/Tor    Minor               NaN
# 28935                            Core Tor/Tor    Minor             fixed
# 28937                            Core Tor/Nyx    Minor             fixed
# 28964                            Core Tor/Tor    Minor               NaN
# 28966                            Core Tor/Tor    Minor         not a bug
# 28967                            Core Tor/Tor    Minor               NaN
#
#                      Created               Modified Actual Points Points  \
# 1732   29 jul. 2011 18:50:33  31 ago. 2017 13:58:38           NaN    NaN
# 28390      NaN     NaN         pabs
# 28405      NaN     NaN      tomreyn
# 28409      NaN     NaN      anarcat
# 28412      NaN     NaN         teor
# 28413      NaN     NaN         teor
# 28418      NaN     NaN      anarcat
# 28420      NaN     NaN       woyazi
# 28435      NaN     NaN     krichter
# 28436      NaN     NaN    0xrichard
# 28437      NaN     NaN    0xrichard
# 28442    nickm     NaN      paldium
# 28446      NaN     NaN         teor
# 28447      NaN     NaN         teor
# 28450      NaN     NaN         teor
# 28451      NaN     NaN        nickm
# 28784      NaN     NaN      yawning
# 28841      NaN     NaN       seeess
# 28845      NaN     NaN      karsten
# 28849      NaN     NaN        amonk
# 28861      NaN     NaN    NtService
# 28883      NaN     NaN      yawning
# 28885      NaN     NaN         isis
# 28899      NaN     NaN         teor
# 28920      NaN     NaN         teor
# 28935     isis     NaN         teor
# 28937      NaN     NaN        torix
# 28964      NaN     NaN  cypherpunks
# 28966      NaN     NaN  cypherpunks
# 28967      NaN     NaN  cypherpunks
#
# [282 rows x 17 columns]

# %%
not_sponsored_work.query('Type=="defect"')['Priority'].value_counts().plot.barh()

# %%
not_sponsored_work.query('Type=="defect"').query('Priority=="Low"')
# Out:
#           id                                            Summary  \
# 25683      3  changing PublicKeyLifetime to smaller values i...
# 25684      4                   Incorrect node routing with mbox
# 25685      6         Confused server clocks can screw up timing
# 25686      7               client 'flush' takes too much memory
# 25687      8          List of servers has names right justified
# 25688      9             Client MMTP timeouts don't really work
# 25689     12  AttributeError: 'module' object has no attribu...
# 25690     13  IOError: [Errno 2] No such file or directory: ...
# 25691     14  This server's files are stored in an older format
# 25692     16  AttributeError: 'NoneType' object has no attri...
# 25693     17                                 minor formatig bug
# 25694     18  TypeError: not enough arguments for format string
# 25695     19  directory permission error shouldn't be an exc...
# 25696     20                                  packaging issues.
# 25697     21  generate-surb closes stdout, breaks 'mixminion...
# 25698     22                   --quiet doesn't work for clients
# 25699     23  Contact Info in directory entry is not compulsory
# 25700     24                           Tight loop in async code
# 25701     25                                   Log files in UTC
# 25702     26                               cannot send 10M file
# 25703     27  Exception while cleaning; shutting down thread...
# 25704     29  traceback happens occasionally during queue or...
# 25705     30                multiple client processes colliding
# 25706     31  mixminion reassemble PqEYO0ly9UZb -o foo  give...
# 25707     32           reassembled message does not match sent.
# 25708     33  please don't create files if you have nothing ...
# 25709     34  reassemble throws exception: NameError: global...
# 25710     35          reassemble's output is one byte too long.
# 25711     36                              Man page typo for  -F
# 25712     37          mixminion crashes if name resolution fail
# ...      ...                                                ...
# 28376  28913  Base32_decode should return the length of its ...
# 28377  28944                  Debian logrotate misses line "su"
# 28378  28956                              Github nyx repository
# 28383  29037                      Why am I still being tracked?
# 28384  29055  Add synonym OnionService* to HiddenService* to...
# 28387  29110  Allow passing seed value to slow/prop_distr/* ...
# 28390  29164  with dark desktop theme: unreadable guard text...
# 28403  29573    Tests fail without network interface configured
# 28405  29621               Systemd Tor service starts too early
# 28406  29636  Document how we estimate users by transport by...
# 28409  29674                      silence or uninstall logwatch
# 28412  29712  sbws should use 1024 to convert kilobytes to b...
# 28413  29741  Work out how to fail chutney travis jobs when ...
# 28417  29841                  ipsec VPN generates gigantic logs
# 28418  29846         fstrim script makes noises on some servers
# 28420  29870      Tor Browser hotkeys stop working unexpectedly
# 28421  29908  on 'Documentation' page of torproject.org, lin...
# 28428  30097                  Circuit UI not shown in FTP pages
# 28435  30416                         Enforce cooperation sanity
# 28436  30422  test.integ.control.controller failing for tor 2.x
# 28437  30453                         Failing tests on travis ci
# 28439  30511                               Remove OnIceComplete
# 28440  30526          Tests should not load system geoip files.
# 28442  30561  Fixed tor_vasprintf on systems without vasprintf.
# 28445  30706               Do some simple BridgeDB housekeeping
# 28446  30723  Work out why no measurements are excluded beca...
# 28447  30724  Work out why relay_in_recent_consensus_count i...
# 28448  30732    "Your Firefox is critically out of date" banner
# 28450  30858  Load geoip and geoip6 files during the unit tests
# 28451  30920     Detect uint64 overflow in config_parse_units()
#
#                   Status         Owner    Type Priority           Milestone  \
# 25683             closed         nickm  defect      Low                 NaN
# 25684             closed         nickm  defect      Low                 NaN
# 25685             closed         nickm  defect      Low                 NaN
# 25686             closed         nickm  defect      Low                 NaN
# 25687             closed         nickm  defect      Low                 NaN
# 25688             closed         nickm  defect      Low                 NaN
# 25689             closed         nickm  defect      Low                 NaN
# 25690             closed         nickm  defect      Low                 NaN
# 25691             closed         nickm  defect      Low                 NaN
# 25692             closed         nickm  defect      Low                 NaN
# 25693             closed         nickm  defect      Low                 NaN
# 25694             closed         nickm  defect      Low                 NaN
# 25695             closed         nickm  defect      Low                 NaN
# 25696             closed         nickm  defect      Low                 NaN
# 25697             closed         nickm  defect      Low                 NaN
# 25698             closed         nickm  defect      Low                 NaN
# 25699             closed         nickm  defect      Low                 NaN
# 25700             closed         nickm  defect      Low                 NaN
# 25701             closed         nickm  defect      Low                 NaN
# 25702             closed         nickm  defect      Low                 NaN
# 25703             closed         nickm  defect      Low                 NaN
# 25704             closed         nickm  defect      Low                 NaN
# 25705             closed         nickm  defect      Low                 NaN
# 25706             closed         nickm  defect      Low                 NaN
# 25707             closed         nickm  defect      Low                 NaN
# 25708             closed         nickm  defect      Low                 NaN
# 25709             closed         nickm  defect      Low                 NaN
# 25710             closed         nickm  defect      Low                 NaN
# 25711             closed         nickm  defect      Low                 NaN
# 25712             closed         nickm  defect      Low                 NaN
# ...                  ...           ...     ...      ...                 ...
# 28376             closed         nickm  defect      Low  Tor: 0.4.1.x-final
# 28377  needs_information           NaN  defect      Low  Tor: 0.4.2.x-final
# 28378                new          hiro  defect      Low                 NaN
# 28383             closed      tbb-team  defect      Low                 NaN
# 28384             closed           NaN  defect      Low    Tor: unspecified
# 28387                new           NaN  defect      Low    Tor: unspecified
# 28390                new      tbb-team  defect      Low                 NaN
# 28403  needs_information        rl1987  defect      Low    Tor: unspecified
# 28405                new           NaN  defect      Low                 NaN
# 28406                new  metrics-team  defect      Low                 NaN
# 28409             closed       anarcat  defect      Low                 NaN
# 28412             closed           NaN  defect      Low   sbws: 1.0.x-final
# 28413                new           NaN  defect      Low                 NaN
# 28417             closed        weasel  defect      Low                 NaN
# 28418                new           tpa  defect      Low                 NaN
# 28420  needs_information      tbb-team  defect      Low                 NaN
# 28421             closed          hiro  defect      Low                 NaN
# 28428                new      tbb-team  defect      Low                 NaN
# 28435                new        alison  defect      Low                 NaN
# 28436             closed        atagar  defect      Low                 NaN
# 28437             closed        atagar  defect      Low                 NaN
# 28439             closed           NaN  defect      Low                 NaN
# 28440                new           NaN  defect      Low    Tor: unspecified
# 28442        merge_ready           NaN  defect      Low  Tor: 0.4.0.x-final
# 28445             closed           phw  defect      Low                 NaN
# 28446                new           NaN  defect      Low   sbws: 1.1.x-final
# 28447                new           NaN  defect      Low   sbws: 1.1.x-final
# 28448  needs_information      tbb-team  defect      Low                 NaN
# 28450           assigned          teor  defect      Low    Tor: unspecified
# 28451                new           NaN  defect      Low  Tor: 0.4.2.x-final
#
#                                     Component Severity Resolution  \
# 25683                        Mixminion-Server      NaN      Fixed
# 25684                        Mixminion-Client      NaN      Fixed
# 25685                        Mixminion-Server   Normal    wontfix
# 25686                        Mixminion-Server      NaN      Fixed
# 25687                        Mixminion-Server      NaN      Fixed
# 25688                        Mixminion-Client      NaN      Fixed
# 25689                        Mixminion-Server      NaN      Fixed
# 25690                        Mixminion-Server      NaN      Fixed
# 25691                        Mixminion-Server      NaN      Fixed
# 25692                        Mixminion-Client      NaN      Fixed
# 25693                        Mixminion-Client      NaN      Fixed
# 25694                        Mixminion-Server      NaN      Fixed
# 25695                        Mixminion-Server      NaN      Fixed
# 25696                        Mixminion-Server      NaN      Fixed
# 25697                        Mixminion-Client      NaN      Fixed
# 25698                        Mixminion-Client      NaN      Fixed
# 25699                        Mixminion-Server      NaN      Fixed
# 25700                        Mixminion-Server      NaN      Fixed
# 25701                        Mixminion-Client      NaN      Fixed
# 25702                        Mixminion-Client      NaN      Fixed
# 25703                        Mixminion-Server      NaN      Fixed
# 25704                        Mixminion-Client      NaN      Fixed
# 25705                         Mixminion-Other   Normal    wontfix
# 25706                        Mixminion-Client      NaN      Fixed
# 25707                        Mixminion-Client      NaN      Fixed
# 25708                        Mixminion-Client      NaN      Fixed
# 25709                        Mixminion-Client      NaN      Fixed
# 25710                        Mixminion-Client      NaN      Fixed
# 25711                        Mixminion-Client      NaN      Fixed
# 25712                        Mixminion-Server      NaN      Fixed
# ...                                       ...      ...        ...
# 28376                            Core Tor/Tor   Normal      fixed
# 28377                            Core Tor/Tor   Normal        NaN
# 28378  Internal Services/Service - github tpo    Minor        NaN
# 28383                Applications/Tor Browser   Normal  not a bug
# 28384                            Core Tor/Tor   Normal  duplicate
# 28387                            Core Tor/Tor   Normal        NaN
# 28390                Applications/Tor Browser    Minor        NaN
# 28403                            Core Tor/Tor   Normal        NaN
# 28405                                Core Tor    Minor        NaN
# 28406                         Metrics/Website   Normal        NaN
# 28409     Internal Services/Tor Sysadmin Team    Minor      fixed
# 28412                           Core Tor/sbws    Minor  not a bug
# 28413                        Core Tor/Chutney    Minor        NaN
# 28417     Internal Services/Tor Sysadmin Team   Normal      fixed
# 28418     Internal Services/Tor Sysadmin Team    Minor        NaN
# 25691      NaN     NaN         weasel
# 25692      NaN     NaN         weasel
# 25693      NaN     NaN         weasel
# 25694      NaN     NaN         weasel
# 25695      NaN     NaN         weasel
# 25696      NaN     NaN         weasel
# 25697      NaN     NaN         weasel
# 25698      NaN     NaN         weasel
# 25699      NaN     NaN         weasel
# 25700      NaN     NaN         weasel
# 25701      NaN     NaN         weasel
# 25702      NaN     NaN         weasel
# 25703      NaN     NaN         weasel
# 25704      NaN     NaN         weasel
# 25705      NaN     NaN         weasel
# 25706      NaN     NaN         weasel
# 25707      NaN     NaN         weasel
# 25708      NaN     NaN         weasel
# 25709      NaN     NaN         weasel
# 25710      NaN     NaN         weasel
# 25711      NaN     NaN         weasel
# 25712      NaN     NaN         weasel
# ...        ...     ...            ...
# 28376  dgoulet     NaN          nickm
# 28377      NaN     NaN           Ilka
# 28378      NaN     NaN         atagar
# 28383      NaN     NaN     Michael303
# 28384      NaN     NaN            s7r
# 28387      NaN     NaN            ahf
# 28390      NaN     NaN           pabs
# 28403      NaN     NaN      atsampson
# 28405      NaN     NaN        tomreyn
# 28406      NaN     NaN           arma
# 28409      NaN     NaN        anarcat
# 28412      NaN     NaN           teor
# 28413      NaN     NaN           teor
# 28417      NaN     NaN        anarcat
# 28418      NaN     NaN        anarcat
# 28420      NaN     NaN         woyazi
# 28421      NaN     NaN  drjohnson1984
# 28428      NaN     NaN           acat
# 28435      NaN     NaN       krichter
# 28436      NaN     NaN      0xrichard
# 28437      NaN     NaN      0xrichard
# 28439      NaN     NaN        arlolra
# 28440      NaN     NaN          nickm
# 28442    nickm     NaN        paldium
# 28445   sysrqb     NaN            phw
# 28446      NaN     NaN           teor
# 28447      NaN     NaN           teor
# 28448      NaN     NaN    hellomebois
# 28450      NaN     NaN           teor
# 28451      NaN     NaN          nickm
#
# [1878 rows x 17 columns]

# %%
not_sponsored_work.query('Type=="defect"').query('Severity=="Normal"')
# Out:
#           id                                            Summary    Status  \
# 0       1968  window.name is persistent across torbutton toggle    closed
# 1       1999  1.3.x: tor:// URL support may allow attacks on...    closed
# 2       2011  Torbutton alpha Preferences dialog OK button d...    closed
# 3       2025               1.3.x: Non-tor cookies not protected    closed
# 4       2028      Reproduce gmail PDF issue w/ debug log output    closed
# 5       2148  1.3.x: RefSpoofer fails on 5 test cases out of...    closed
# 6       2193           Facebook <securecookie> rules break apps    closed
# 7       2204  Recent openssls (1.0.0b and 0.9.8p) break rela...    closed
# 9       2312            TBB for Linux tarball contains symlinks    closed
# 10      2359       Error prevents display of gitweb.tpo/tor.git    closed
# 11      2421  Torbutton Exception in sandbox evaluation., Da...    closed
# 12      2428  nytimes.com login page loads after Torbutton t...    closed
# 16      2633  "Torbutton Exception in sandbox evaluation. Da...    closed
# 17      2780  Investigate Torbutton translation input valida...    closed
# 18      2828  FF4 tor browser bundle for linux missing exten...    closed
# 19      2868  Fix weird torperf results due to bad guard cho...    closed
# 20      3005  TorButton breaks posting text (subject and bod...    closed
# 22      3433  pages do not load correctly when tor button is...    closed
# 23      3554  TBB should not disable addon updates until Tha...    closed
# 24      3597  betterprivacy included in TBB deletes all Flas...    closed
# 26      3691            Cookies mismatch issues on google sites    closed
# 27      3738                   weird behavior in Vidalia 0.2.13    closed
# 28      3790          Debian package for torouter-tui is broken    closed
# 29      3801  Library filenames in TBB for Linux 1.1.13 do n...    closed
# 33      3906             TBB for Linux ships exploitable libpng    closed
# 34      4093  TBB for OSX logs everything to /var/log/system...    closed
# 35      4192  make Tor Browser fail to connect when not laun...    closed
# 36      4263                TBB on Mac OS X 10.5.8 fails to run    closed
# 37      4384           Trac is fascist about child ticket types    closed
# 38      4450                           New Tor image won't boot    closed
# ...      ...                                                ...       ...
# 28741  12685          Wrap fingerprint line on smaller displays    closed
# 28744  12799  fingerprints - descriptor Space removal, case ...       new
# 28749  12970      dir-spec's a-line shouldn't mention portlists    closed
# 28752  13273  Clarify verifying-signatures.html for builds n...    closed
# 28756  13456     Tor Launcher should start centered on all OSes       new
# 28757  13459  About Tor Button Window Too Short on OS X Mave...    closed
# 28773  14066  SIGHUP: Reloading config and does not reset in...       new
# 28778  14211    --data-dir argument is not properly recognized.       new
# 28792  15333                Minor control-spec.txt corrections.    closed
# 28794  15380               log messages are doubled and unclear       new
# 28795  15381  cosmetic issue in log message : v0.1.2.3 versu...    closed
# 28803  15661  Same "non-loopback address" notice is printed ...       new
# 28812  16119                        Can't access crunchbang.org    closed
# 28815  16418                       Typo "continium" in ooni-api    closed
# 28820  16598  fsync ed25519 master key files before closing ...  assigned
# 28823  16759   Typo in a Tor Messenger string (xmpp.properties)    closed
# 28835  17438  if HSDir is set then report a (blurred) uptime...    closed
# 28839  17515                               Update README.1st.md    closed
# 28852  17941                        link corruptive chroot-jail    closed
# 28854  17954                              typo french about:tor    closed
# 28855  17955                           overlap french about:tor    closed
# 28894  20447  Tor Browser Spec is not accurate regarding Ses...    closed
# 28913  22161                  check.torproject.org false report    closed
# 28918  22382       Fix fd leak-on-close from tor-fw-helper pipe       new
# 28931  24238  Bug: Generated a networkstatus vote we couldn'...       new
# 28940  25462  Tor volunteer's page links to a youtube channe...    closed
# 28942  25665  Investigate differences between ant task 'run-...    closed
# 28944  25965  Document default value of Nickname parameter [...    closed
# 28947  26076  test_keygen.sh and test_key_expiration.sh fail...       new
# 28963  29480               Expose bridge pool assignments again       new
#
#            Owner    Type   Priority                      Milestone  \
# 0      mikeperry  defect  Immediate                            NaN
# 1      mikeperry  defect  Immediate                 Torbutton: 1.3
# 2      mikeperry  defect  Immediate                 Torbutton: 1.3
# 3      mikeperry  defect  Immediate                 Torbutton: 1.3
# 4      mikeperry  defect  Immediate                            NaN
# 5      mikeperry  defect  Immediate                 Torbutton: 1.3
# 6            pde  defect  Immediate                            NaN
# 7            NaN  defect  Immediate                            NaN
# 9        rransom  defect  Immediate                            NaN
# 10     mikeperry  defect  Immediate                            NaN
# 11     mikeperry  defect  Immediate                            NaN
# 12     mikeperry  defect  Immediate                            NaN
# 16     mikeperry  defect  Immediate                            NaN
# 17     mikeperry  defect  Immediate                            NaN
# 18         erinn  defect  Immediate                            NaN
# 19     mikeperry  defect  Immediate                            NaN
# 20     mikeperry  defect  Immediate                            NaN
# 22     mikeperry  defect  Immediate                            NaN
# 23         erinn  defect  Immediate  TorBrowserBundle 2.2.x-stable
# 24         erinn  defect  Immediate  TorBrowserBundle 2.2.x-stable
# 26         erinn  defect  Immediate                            NaN
# 27        chiiph  defect  Immediate                            NaN
# 28       ioerror  defect  Immediate                            NaN
# 29         erinn  defect  Immediate                            NaN
# 33         erinn  defect  Immediate  TorBrowserBundle 2.2.x-stable
# 34         erinn  defect  Immediate                            NaN
# 35     mikeperry  defect  Immediate                            NaN
# 36         erinn  defect  Immediate                            NaN
# 37         erinn  defect  Immediate                            NaN
# 38          runa  defect  Immediate                            NaN
# ...          ...     ...        ...                            ...
# 28741        irl  defect   Very Low                            NaN
# 28744        NaN  defect   Very Low               Tor: unspecified
# 28749      nickm  defect   Very Low             Tor: 0.3.1.x-final
# 28752        NaN  defect   Very Low                            NaN
# 28756      brade  defect   Very Low                            NaN
# 28757   tbb-team  defect   Very Low                            NaN
# 28773        NaN  defect   Very Low               Tor: unspecified
# 28778        NaN  defect   Very Low                            NaN
# 28792      nickm  defect   Very Low             Tor: 0.3.2.x-final
# 28794        NaN  defect   Very Low               Tor: unspecified
# 28795        NaN  defect   Very Low             Tor: 0.2.9.x-final
# 28803        NaN  defect   Very Low               Tor: unspecified
# 28812   tbb-team  defect   Very Low                            NaN
# 28815    hellais  defect   Very Low                            NaN
# 28820        NaN  defect   Very Low               Tor: unspecified
# 28823        NaN  defect   Very Low                            NaN
# 28835        NaN  defect   Very Low               Tor: unspecified
# 28839        NaN  defect   Very Low             Tor: 0.2.8.x-final
# 28852        NaN  defect   Very Low                            NaN
# 28854   tbb-team  defect   Very Low                            NaN
# 28855   tbb-team  defect   Very Low                            NaN
# 28894   tbb-team  defect   Very Low                            NaN
# 28913    arlolra  defect   Very Low                            NaN
# 28918        NaN  defect   Very Low               Tor: unspecified
# 28931        NaN  defect   Very Low               Tor: unspecified
# 28940        NaN  defect   Very Low                            NaN
# 28942     iwakeh  defect   Very Low                            NaN
# 28944        NaN  defect   Very Low             Tor: 0.3.4.x-final
# 28947        NaN  defect   Very Low               Tor: unspecified
# 28963     sysrqb  defect   Very Low                            NaN
#
#                                    Component Severity        Resolution  \
# 0                     Applications/Torbutton   Normal             fixed
# 1                     Applications/Torbutton   Normal             fixed
# 2                     Applications/Torbutton   Normal             fixed
# 3                     Applications/Torbutton   Normal           invalid
# 4                     Applications/Torbutton   Normal           invalid
# 5                     Applications/Torbutton   Normal             fixed
# 6      HTTPS Everywhere/EFF-HTTPS Everywhere   Normal       implemented
# 7                               Core Tor/Tor   Normal             fixed
# 9      Applications/Tor bundles/installation   Normal             fixed
# 10                    Applications/Torbutton   Normal             fixed
# 11                    Applications/Torbutton   Normal             fixed
# 12                    Applications/Torbutton   Normal             fixed
# 16                    Applications/Torbutton   Normal        worksforme
# 17                    Applications/Torbutton   Normal             fixed
# 18     Applications/Tor bundles/installation   Normal             fixed
# 19                          Archived/Torperf   Normal             fixed
# 20                          TorBrowserButton   Normal  user disappeared
# 22                      Firefox Patch Issues   Normal           invalid
# 23     Applications/Tor bundles/installation   Normal             fixed
# 24     Applications/Tor bundles/installation   Normal             fixed
# 26     Applications/Tor bundles/installation   Normal  user disappeared
# 27                          Archived/Vidalia   Normal             fixed
# 28                         Archived/Torouter   Normal           wontfix
# 29     Applications/Tor bundles/installation   Normal             fixed
# 33     Applications/Tor bundles/installation   Normal             fixed
# 34     Applications/Tor bundles/installation   Normal             fixed
# 35                      Firefox Patch Issues   Normal             fixed
# 36     Applications/Tor bundles/installation   Normal             fixed
# 37          Internal Services/Service - trac   Normal         duplicate
# 38                        Archived/Tor Cloud   Normal             fixed
# ...                                      ...      ...               ...
# 28741                   Metrics/Relay Search   Normal             fixed
# 28744                           Core Tor/Tor   Normal               NaN
# 28749                           Core Tor/Tor   Normal             fixed
# 28752                       Webpages/Website   Normal             fixed
# 28756              Applications/Tor Launcher   Normal               NaN
# 28757               Applications/Tor Browser   Normal             fixed
# 28773                           Core Tor/Tor   Normal               NaN
# 28778                     Archived/Obfsproxy   Normal               NaN
# 28792                           Core Tor/Tor   Normal             fixed
# 28794                           Core Tor/Tor   Normal               NaN
# 28795                           Core Tor/Tor   Normal             fixed
# 28803                           Core Tor/Tor   Normal               NaN
# 28812               Applications/Tor Browser   Normal  user disappeared
# 28815                          Archived/Ooni   Normal             fixed
# 28820                           Core Tor/Tor   Normal               NaN
# 28823                 Archived/Tor Messenger   Normal           wontfix
# 28835                           Core Tor/Tor   Normal           invalid
# 28839                           Core Tor/Tor   Normal             fixed
# 28852                           Core Tor/Tor   Normal             fixed
# 28854               Applications/Tor Browser   Normal           wontfix
# 28855               Applications/Tor Browser   Normal           wontfix
# 28894               Applications/Tor Browser   Normal         duplicate
# 28913                 Applications/Tor Check   Normal         duplicate
# 28918                           Core Tor/Tor   Normal               NaN
# 28931                           Core Tor/Tor   Normal               NaN
# 28940                       Webpages/Website   Normal         duplicate
# 28942                        Metrics/Website   Normal        worksforme
# 28944                           Core Tor/Tor   Normal       implemented
# 28947                           Core Tor/Tor   Normal               NaN
# 28963                 Circumvention/BridgeDB   Normal               NaN
#
#                      Created               Modified Actual Points Points  \
# 0      23 sep. 2010 01:52:04   6 dic. 2017 04:45:21             6      8
# 1       2 oct. 2010 21:46:13   6 dic. 2017 04:45:21             2      2
# 2       5 oct. 2010 06:27:31   6 dic. 2017 04:45:21           NaN    NaN
# 3       8 oct. 2010 01:04:21   6 dic. 2017 04:45:21             1      1
# 4       9 oct. 2010 05:11:15   6 dic. 2017 04:45:21             1      2
# 5       1 nov. 2010 14:10:24   6 dic. 2017 04:45:21             8      6
# 6      15 nov. 2010 19:57:21   6 dic. 2017 04:45:21           NaN    NaN
# 7      20 nov. 2010 13:44:52   6 dic. 2017 04:45:21           NaN    NaN
# 9      24 dic. 2010 06:10:01   6 dic. 2017 04:45:21           NaN    NaN
# 10      7 ene. 2011 01:19:41   6 dic. 2017 04:45:21             2      4
# 11     20 ene. 2011 19:28:18   6 dic. 2017 04:45:21             1      1
# 12     24 ene. 2011 07:19:11   6 dic. 2017 04:45:21             3     10
# 28854  29 dic. 2015 14:23:19  12 ene. 2016 08:38:52           NaN    NaN
# 28855  29 dic. 2015 14:28:21  12 ene. 2016 08:38:18           NaN    NaN
# 28894  24 oct. 2016 16:39:28  24 feb. 2017 20:14:48           NaN    NaN
# 28913   4 may. 2017 22:42:22   5 may. 2017 09:05:50           NaN    NaN
# 28918  25 may. 2017 15:28:19  11 jul. 2017 15:26:55           NaN    NaN
# 28931  11 nov. 2017 05:10:06  25 mar. 2018 02:35:36           NaN    NaN
# 28940  11 mar. 2018 11:44:08  11 mar. 2018 11:54:53           NaN    NaN
# 28942  28 mar. 2018 10:56:54  18 may. 2018 10:09:01           NaN    NaN
# 28944  29 abr. 2018 13:07:22   7 may. 2018 17:31:14           NaN    NaN
# 28947  11 may. 2018 02:07:21  18 jul. 2018 02:27:34           NaN    NaN
# 28963  12 feb. 2019 15:30:20   6 abr. 2019 01:13:41           NaN    NaN
#
#       Reviewer Sponsor            Reporter
# 0          NaN     NaN            katmagic
# 1          NaN     NaN             rransom
# 2          NaN     NaN             rransom
# 3          NaN     NaN              downie
# 4          NaN     NaN           mikeperry
# 5          NaN     NaN  T(A)ILS developers
# 6          NaN     NaN                 pde
# 7          NaN     NaN               stars
# 9          NaN     NaN             rransom
# 10         NaN     NaN             rransom
# 11         NaN     NaN              valdis
# 12         NaN     NaN             rransom
# 16         NaN     NaN             bouazza
# 17         NaN     NaN           mikeperry
# 18         NaN     NaN              phobos
# 19         NaN     NaN           mikeperry
# 20         NaN     NaN                HG2G
# 22         NaN     NaN                  A2
# 23         NaN     NaN           mikeperry
# 24         NaN     NaN         cypherpunks
# 26         NaN     NaN                G-Lo
# 27         NaN     NaN               erinn
# 28         NaN     NaN                runa
# 29         NaN     NaN             rransom
# 33         NaN     NaN             rransom
# 34         NaN     NaN              phobos
# 35         NaN     NaN             ioerror
# 36         NaN     NaN             ioerror
# 37         NaN     NaN             rransom
# 38         NaN     NaN                runa
# ...        ...     ...                 ...
# 28741      NaN     NaN               Zitlo
# 28744      NaN     NaN            grarpamp
# 28749      NaN     NaN              atagar
# 28752      NaN     NaN              seeess
# 28756      NaN     NaN             Sherief
# 28757      NaN     NaN                teor
# 28773      NaN     NaN                Sasi
# 28778      NaN     NaN          masterkorp
# 28792      NaN     NaN             yawning
# 28794      NaN     NaN              toralf
# 28795      NaN     NaN              toralf
# 28803      NaN     NaN         yurivict271
# 28812      NaN     NaN         thisisweird
# 28815      NaN     NaN                 dcf
# 28820      NaN     NaN               nickm
# 28823      NaN     NaN              issyl0
# 28835      NaN     NaN              toralf
# 28839      NaN     NaN              ckomlo
# 28852      NaN     NaN               tscpd
# 28854      NaN     NaN               tscpd
# 28855      NaN     NaN               tscpd
# 28894      NaN     NaN                 tom
# 28913      NaN     NaN               desci
# 28918      NaN     NaN               nickm
# 28931      NaN     NaN           Sebastian
# 28940      NaN     NaN                ggus
# 28942      NaN     NaN              iwakeh
# 28944      NaN     NaN               saper
# 28947      NaN     NaN               saper
# 28963      NaN     NaN                 irl
#
# [8956 rows x 17 columns]
