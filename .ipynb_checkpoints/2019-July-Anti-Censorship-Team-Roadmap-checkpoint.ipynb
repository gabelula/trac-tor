# %%
# All tickets in the roadmap for July for the anti censroship team roadmap
# Query https://trac.torproject.org/projects/tor/query?status=accepted&status=assigned&status=closed&status=merge_ready&status=needs_information&status=needs_review&status=needs_revision&status=new&status=reopened&keywords=~anti-censorship-roadmap-july&col=id&col=summary&col=keywords&col=status&col=owner&col=type&col=priority&col=resolution&col=actualpoints&col=points&col=sponsor&order=status

csv_path='/Users/gaba/Code/torproject/trac/datasets/AntiCensorshipTeam-Roadmap-July-2019.csv'

import pandas as pd
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np

csv_file = pd.read_csv(csv_path)

# %%
# which sponsors got ticket closed
sponsors_by_tickets_closed = csv_file['Sponsor'].value_counts()

objects = tuple(sponsors_by_tickets_closed.keys())
y_pos = np.arange(len(objects))
performance = list(sponsors_by_tickets_closed)

plt.barh(y_pos, performance, align='center', alpha=0.5)
plt.yticks(y_pos, objects)
plt.xlabel('tickets closed')
plt.title('Tickets closed by Sponsor')

plt.show()

# %%
# who closed tickets
csv_file['Owner'].value_counts()
# Out:
# cohosh     1
# arlolra    1
# Name: Owner, dtype: int64

# %%
# What type of tickets we got
csv_file['Type'].value_counts().plot.barh()

# %%
# How many high and very high tickets
csv_file['Priority'].value_counts()
# Out:
# Medium       125
# High          12
# Low            8
# Very High      3
# Immediate      1
# Very Low       1
# Name: Priority, dtype: int64

# %%
# which milestone the tickets were for
csv_file['Milestone'].value_counts()
# Out:
# Tor: 0.4.1.x-final    9
# Tor: 0.4.0.x-final    6
# Tor: 0.3.5.x-final    5
# Tor: unspecified      1
# Tor: 0.3.4.x-final    1
# Name: Milestone, dtype: int64

# %%
# How many 'big' tickets got resolved
csv_file['Points'].value_counts()
# Out:
# 0.1     27
# 1.0     16
# 0.2     12
# 0.5      9
# 0.0      6
# 3.0      4
# 0.3      2
# 15.0     2
# 2.0      2
# 10.0     2
# Name: Points, dtype: int64

# %%
# How tickets got resolved
csv_file['Resolution'].value_counts()
# Out:
# fixed               85
# implemented         22
# duplicate           13
# wontfix              8
# not a bug            7
# user disappeared     2
# worksforme           2
# invalid              1
# Name: Resolution, dtype: int64

# %%
# How many days took to complete the ticket versus estimation
csv_file.filter(items=['Sponsor', 'Points', 'Actual Points']).groupby('Sponsor').sum().plot.barh()

# %%
# Velocity for the month of April

csv_file.filter(items=['Actual Points']).sum()

# Estimation of capacity for April
# Calculated here: https://nc.riseup.net/apps/onlyoffice/270863?filePath=%2FDocuments%2FTeams%2FNetwork%2FTeam%20Capacity.xlsx
# Out:
# Actual Points    24.0
# dtype: float64

# %%
# How much work was not sponsored

sponsor_and_not = csv_file['Sponsor'].notnull().value_counts().rename(lambda x: 'Sponsored' if x else 'Not Sponsored')

sponsor_and_not.plot.barh()

# %%
# From all not sponsored work which releases they went into

not_sponsored_work = csv_file[csv_file.Sponsor.isnull()]
not_sponsored_work['Milestone'].value_counts().plot.barh()

# %%
# What is this non sponsored work

not_sponsored_work['Type'].value_counts().plot.barh()

# %%
# We understnd bugs and want to track which specific non sponsored enhancement we are prioritizing. 
not_sponsored_work.query('Type=="enhancement"')

# It seems that this are all tickets that were: 
# . closed some time ago but just recently commented.
# . tickets that volunteers worked on
# . updates to scripts (like #30114)
# Out:
#         id                                            Summary Sponsor  \
# 1    24902             Denial of Service mitigation subsystem     NaN
# 2    29357               add an ActiveOnStartup config option     NaN
# 4    21377      DirAuths should expose bwauth bandwidth files     NaN
# 16   22022        Move to cryptography for ed25519 validation     NaN
# 22   26937     sbws: Warn when there is not enough disk space     NaN
# 36   28495    Please provide a parser for detached signatures     NaN
# 74   29992                    Update to April GeoIP2 database     NaN
# 88   30114      Also fetch tor-github when we git-pull-all.sh     NaN
# 92   30122  Make stem's unit tests propagate the backtrace...     NaN
# 106  30137                                  Update PyPI links     NaN
#
#       Resolution      Component  Status         Type   Priority  \
# 1          fixed   Core Tor/Tor  closed  enhancement  Very High
# 2          fixed   Core Tor/Tor  closed  enhancement  Very High
# 4          fixed   Core Tor/Tor  closed  enhancement       High
# 16   implemented  Core Tor/Stem  closed  enhancement     Medium
# 22         fixed  Core Tor/sbws  closed  enhancement     Medium
# 36         fixed  Core Tor/Stem  closed  enhancement     Medium
# 74   implemented   Core Tor/Tor  closed  enhancement     Medium
# 88         fixed   Core Tor/Tor  closed  enhancement     Medium
# 92         fixed  Core Tor/Stem  closed  enhancement     Medium
# 106        fixed  Core Tor/Stem  closed  enhancement        Low
#
#               Milestone Severity  Actual Points  Points  \
# 1    Tor: 0.3.3.x-final   Normal            NaN     NaN
# 2    Tor: 0.4.0.x-final   Normal            0.1     0.5
# 4    Tor: 0.4.0.x-final   Normal            0.3     0.2
# 16                  NaN    Minor            NaN     NaN
# 22    sbws: 1.0.x-final   Normal            NaN     NaN
# 36                  NaN   Normal            NaN     NaN
# 74   Tor: 0.2.9.x-final   Normal            NaN     NaN
# 88   Tor: 0.4.1.x-final   Normal            0.1     0.1
# 92                  NaN   Normal            0.6     0.5
# 106                 NaN    Minor            NaN     NaN
#
#                                               Keywords
# 1    tor-dos, tor-relay, review-group-30, 029-backp...
# 2                    tbb-needs, 040-proposed, 040-must
# 4    authority-test-done, tor-dirauth, metrics-need...
# 16                             descriptor unactionable
# 22                                                 NaN
# 36                                                 NaN
# 74   tor-client, tor-relay, 029-backport, 032-backp...
# 88                    git-scripts, fast-fix, asn-merge
# 92                               tor-ci-fail-sometimes
# 106                                                NaN

# %%
# What are the not sponsored bugs fixed?
not_sponsored_work.query('Type=="defect"')['Severity'].value_counts().plot.barh()

# %%
not_sponsored_work.query('Type=="defect"').query('Severity=="Minor"')
# Out:
#        id                                      Summary Sponsor Resolution  \
# 96  30176  Clear memory in smartlist_remove_keeporder.     NaN      fixed
#
#        Component  Status    Type Priority           Milestone Severity  \
# 96  Core Tor/Tor  closed  defect   Medium  Tor: 0.4.1.x-final    Minor
#
#     Actual Points  Points                                           Keywords
# 96            NaN     NaN  035-backport? 040-backport? defense-in-depth? ...

# %%
not_sponsored_work.query('Type=="defect"')['Priority'].value_counts().plot.barh()

# %%
not_sponsored_work.query('Type=="defect"').query('Priority=="Low"')
# Out:
#         id                                            Summary Sponsor  \
# 102  13221  Misleading error messages about bind_ipv4_only...     NaN
#
#     Resolution     Component  Status    Type Priority           Milestone  \
# 102      fixed  Core Tor/Tor  closed  defect      Low  Tor: 0.3.5.x-final
#
#     Severity  Actual Points  Points  \
# 102   Normal            0.1     0.1
#
#                                               Keywords
# 102  041-proposed, tor-client, easy, logging, messa...

# %%
not_sponsored_work.query('Type=="defect"').query('Severity=="Normal"')
# Out:
#         id                                            Summary Sponsor  \
# 0    26671  V3BWFile.write is not a class/static method, b...     NaN
# 3    29967  CID 1444262: Null-pointer dereference in non-f...     NaN
# 9    29665  hs: circuit_expire_old_circuits_serverside() s...     NaN
# 11   30011      Kill test-stem if takes more than 9.5 minutes     NaN
# 12   30021  Do not cache cipher list classification if cip...     NaN
# 19   24490  Stop setting bridges running in networkstatus_...     NaN
# 21   26644          Don't require sbws tests to set log level     NaN
# 24   27342                           sbws poor error handling     NaN
# 25   27512                    Stop making disk space syscalls     NaN
# 27   27916     Don't print default values for arguments twice     NaN
# 28   27917                         Standardize argument_names     NaN
# 29   27918                    Add types to some new arguments     NaN
# 31   28105  Use secs-away when provided instead of data_pe...     NaN
# 32   28223        Unparseable microdescriptor on public relay     NaN
# 33   28267   Update spec version in the bandwidth file header     NaN
# 34   28268  Change default directories when sbws is run fr...     NaN
# 35   28269  Repeated HSFETCH queries fail with QUERY_NO_HSDIR     NaN
# 38   28547  Monitor relays that are not measured by each s...     NaN
# 39   28563  Work out how sbws can report excluded relays i...     NaN
# 40   28565  Report excluded results in a relay's bandwidth...     NaN
# 41   28567  Report relays that sbws wants to test, but the...     NaN
# 44   28698  When circuit times are fixed, they can't be "r...     NaN
# 47   28861           torsocks: Unsupported syscall number 217     NaN
# 48   29060                 shellcheck: test-network.sh issues     NaN
# 50   29121  tor man page doesn't mention isolating between...     NaN
# 51   29144  Log the correct "auto" port number for listeni...     NaN
# 53   29613  Make relays into exits when ExitRelay is auto ...     NaN
# 54   29640  Improve the monotonic time documentation in co...     NaN
# 55   29703            Backport test-network.sh fixes to 0.2.9     NaN
# 56   29707  sbws does not scale consensus bandwidths to by...     NaN
# 57   29724  Create a blog post about work done and future ...     NaN
# 60   29806          Ignore bandwidth file lines with "vote=0"     NaN
# 61   29853  sbws should show relays for diagnostics, even ...     NaN
# 62   29897  Refactor handle_get_next_bandwidth() to use co...     NaN
# 63   29913         Stop assuming that /usr/bin/python3 exists     NaN
# 67   29939  test_routerkeys: Coverity says, always check m...     NaN
# 68   29959  Actually include the bandwidth file digest in ...     NaN
# 70   29961  Update the Tor version for bandwidth-file-dige...     NaN
# 71   29962  Turn off Travis Rust caching, and see if it sp...     NaN
# 72   29979  Don't recommend expect() in CodingStandardsRus...     NaN
# 75   30001  test failure: dir_handle_get/status_vote_next_...     NaN
# 76   30002          shellcheck: test_key_expiration.sh issues     NaN
# 78   30012  When stem receives a signal, log useful inform...     NaN
# 79   30033  The pre-push hook should call the pre-commit h...     NaN
# 84   30075          shellcheck: contrib/dist/tor.sh.in issues     NaN
# 85   30077     shellcheck: src/test/fuzz/fuzz_multi.sh issues     NaN
# 86   30079        shellcheck: src/test/fuzz/minimize.sh issue     NaN
# 87   30112  Fix outdated comments in dirserv_read_measured...     NaN
# 89   30117         Support stem's backtrace signals in Travis     NaN
# 90   30119  cert-spec uses binary encodings but does not s...     NaN
# 91   30120  pre-commit.git-hook doesn't check for changes ...     NaN
# 93   30149  Fix "medium" and "low" impact coverity false p...     NaN
# 94   30151                     Fix memory leak in tor-resolve     NaN
# 95   30160  Update bandwidth file headers parser to spec v...     NaN
# 97   30180      CID 1444641: REVERSE_INULL in test_hs_cache.c     NaN
# 98   30190      Do not warn about compatible OpenSSL upgrades     NaN
# 102  13221  Misleading error messages about bind_ipv4_only...     NaN
#
#       Resolution          Component  Status    Type   Priority  \
# 0          fixed      Core Tor/sbws  closed  defect  Immediate
# 3          fixed       Core Tor/Tor  closed  defect  Very High
# 9          fixed       Core Tor/Tor  closed  defect       High
# 11         fixed       Core Tor/Tor  closed  defect       High
# 12         fixed       Core Tor/Tor  closed  defect       High
# 19         fixed       Core Tor/Tor  closed  defect     Medium
# 21         fixed      Core Tor/sbws  closed  defect     Medium
# 24         fixed      Core Tor/sbws  closed  defect     Medium
# 25         fixed      Core Tor/sbws  closed  defect     Medium
# 27         fixed      Core Tor/sbws  closed  defect     Medium
# 28         fixed      Core Tor/sbws  closed  defect     Medium
# 29         fixed      Core Tor/sbws  closed  defect     Medium
# 31         fixed      Core Tor/sbws  closed  defect     Medium
# 32         fixed       Core Tor/Tor  closed  defect     Medium
# 33   implemented      Core Tor/sbws  closed  defect     Medium
# 34         fixed      Core Tor/sbws  closed  defect     Medium
# 35   implemented       Core Tor/Tor  closed  defect     Medium
# 38         fixed      Core Tor/sbws  closed  defect     Medium
# 39   implemented      Core Tor/sbws  closed  defect     Medium
# 40   implemented      Core Tor/sbws  closed  defect     Medium
# 41   implemented      Core Tor/sbws  closed  defect     Medium
# 44         fixed       Core Tor/Tor  closed  defect     Medium
# 47         fixed  Core Tor/Torsocks  closed  defect     Medium
# 48   implemented       Core Tor/Tor  closed  defect     Medium
# 50         fixed       Core Tor/Tor  closed  defect     Medium
# 51         fixed       Core Tor/Tor  closed  defect     Medium
# 53   implemented       Core Tor/Tor  closed  defect     Medium
# 54         fixed       Core Tor/Tor  closed  defect     Medium
# 55         fixed       Core Tor/Tor  closed  defect     Medium
# 56         fixed      Core Tor/sbws  closed  defect     Medium
# 57   implemented      Core Tor/sbws  closed  defect     Medium
# 60         fixed       Core Tor/Tor  closed  defect     Medium
# 61         fixed      Core Tor/sbws  closed  defect     Medium
# 62         fixed       Core Tor/Tor  closed  defect     Medium
# 63         fixed       Core Tor/Tor  closed  defect     Medium
# 67         fixed       Core Tor/Tor  closed  defect     Medium
# 68         fixed       Core Tor/Tor  closed  defect     Medium
# 70         fixed       Core Tor/Tor  closed  defect     Medium
# 71         fixed       Core Tor/Tor  closed  defect     Medium
# 72         fixed       Core Tor/Tor  closed  defect     Medium
# 75         fixed       Core Tor/Tor  closed  defect     Medium
# 76         fixed       Core Tor/Tor  closed  defect     Medium
# 78   implemented      Core Tor/Stem  closed  defect     Medium
# 79   implemented       Core Tor/Tor  closed  defect     Medium
# 84   implemented       Core Tor/Tor  closed  defect     Medium
# 85   implemented       Core Tor/Tor  closed  defect     Medium
# 86         fixed       Core Tor/Tor  closed  defect     Medium
# 87         fixed       Core Tor/Tor  closed  defect     Medium
# 89         fixed       Core Tor/Tor  closed  defect     Medium
# 90         fixed       Core Tor/Tor  closed  defect     Medium
# 91         fixed       Core Tor/Tor  closed  defect     Medium
# 93         fixed       Core Tor/Tor  closed  defect     Medium
# 94         fixed       Core Tor/Tor  closed  defect     Medium
# 95   implemented      Core Tor/Stem  closed  defect     Medium
# 97         fixed       Core Tor/Tor  closed  defect     Medium
# 98         fixed       Core Tor/Tor  closed  defect     Medium
# 102        fixed       Core Tor/Tor  closed  defect        Low
#
#               Milestone Severity  Actual Points  Points  \
# 0     sbws: 1.0.x-final   Normal            NaN     NaN
# 3    Tor: 0.4.1.x-final   Normal            0.0     0.0
# 9    Tor: 0.3.4.x-final   Normal            0.1     0.1
# 11   Tor: 0.3.5.x-final   Normal            0.3     0.3
# 12   Tor: 0.2.9.x-final   Normal            0.5     NaN
# 19   Tor: 0.4.1.x-final   Normal            NaN     1.0
# 21    sbws: 1.0.x-final   Normal            NaN     NaN
# 24    sbws: 1.0.x-final   Normal            NaN     NaN
# 25    sbws: 1.0.x-final   Normal            NaN     NaN
# 27    sbws: 1.0.x-final   Normal            NaN     NaN
# 28    sbws: 1.0.x-final   Normal            NaN     NaN
# 29    sbws: 1.0.x-final   Normal            NaN     NaN
# 31    sbws: 1.0.x-final   Normal            NaN     NaN
# 32   Tor: 0.4.0.x-final   Normal            0.2     0.2
# 33    sbws: 1.0.x-final   Normal            NaN     NaN
# 34    sbws: 1.0.x-final   Normal            NaN     NaN
# 35   Tor: 0.4.1.x-final   Normal            NaN     NaN
# 38    sbws: 1.1.x-final   Normal            NaN     NaN
# 39    sbws: 1.1.x-final   Normal            NaN     NaN
# 40    sbws: 1.1.x-final   Normal            NaN     1.0
# 41    sbws: 1.1.x-final   Normal            NaN     1.0
# 44   Tor: 0.3.5.x-final   Normal            0.2     0.2
# 47                  NaN   Normal            NaN     NaN
# 48   Tor: 0.4.1.x-final   Normal            NaN     NaN
# 50   Tor: 0.4.0.x-final   Normal            0.1     0.1
# 51   Tor: 0.3.5.x-final   Normal            0.1     0.1
# 53   Tor: 0.4.1.x-final   Normal            0.1     0.5
# 54   Tor: 0.4.1.x-final   Normal            0.1     0.1
# 55   Tor: 0.2.9.x-final   Normal            0.4     0.5
# 56    sbws: 1.0.x-final   Normal            NaN     NaN
# 57    sbws: 1.1.x-final   Normal            NaN     1.0
# 60   Tor: 0.3.4.x-final   Normal            0.5     1.0
# 61    sbws: 1.1.x-final   Normal            NaN     NaN
# 62   Tor: 0.4.0.x-final   Normal            0.1     0.1
# 63   Tor: 0.4.1.x-final   Normal            0.2     0.1
# 67   Tor: 0.4.1.x-final   Normal            0.0     0.0
# 68   Tor: 0.4.0.x-final   Normal            0.2     0.2
# 70   Tor: 0.4.0.x-final   Normal            0.0     0.0
# 71   Tor: 0.3.4.x-final   Normal            NaN     NaN
# 72   Tor: 0.4.1.x-final   Normal            0.1     0.1
# 75   Tor: 0.4.0.x-final   Normal            0.1     0.1
# 76   Tor: 0.4.1.x-final   Normal            NaN     NaN
# 78                  NaN   Normal            NaN     NaN
# 79   Tor: 0.4.1.x-final   Normal            NaN     NaN
# 84   Tor: 0.4.1.x-final   Normal            NaN     NaN
# 85   Tor: 0.4.1.x-final   Normal            NaN     NaN
# 86   Tor: 0.4.1.x-final   Normal            NaN     NaN
# 87   Tor: 0.4.1.x-final   Normal            0.1     0.1
# 89   Tor: 0.3.5.x-final   Normal            0.4     0.2
# 90     Tor: unspecified   Normal            NaN     0.1
# 91   Tor: 0.4.1.x-final   Normal            0.0     0.0
# 93   Tor: 0.4.1.x-final   Normal            0.1     NaN
# 94   Tor: 0.4.1.x-final   Normal            NaN     NaN
# 95                  NaN   Normal            NaN     1.0
# 97   Tor: 0.4.1.x-final   Normal            0.0     0.0
# 98   Tor: 0.4.1.x-final   Normal            NaN     0.2
# 102  Tor: 0.3.5.x-final   Normal            0.1     0.1
#
#                                               Keywords
# 0                                         sbws-1.0must
# 3               regression, crash, asn-merge, coverity
# 9    tor-hs, tor-relay, 029-backport, 034-backport,...
# 11   tor-ci-fail-sometimes, 035-backport, 040-backport
# 12   tor-ci-fail-sometimes, ci, stem, ssl, 029-back...
# 19             easy, intro, refactor, code-correctness
# 21                                                 NaN
# 24                                                 NaN
# 25                                                 NaN
# 27                                                 NaN
# 28                                                 NaN
# 29                                                 NaN
# 31                                                 NaN
# 32   040-roadmap-proposed, regression?, 035-can, po...
# 33                                                 NaN
# 34                                                 NaN
# 35                        tor-hs, tor-control tor-spec
# 38   tor-bwauth, sbws-1.0-must-moved-20181128, sbws...
# 39   tor-bwauth, sbws-1.0-must-moved-20181128, sbws...
# 40   tor-bwauth, sbws-1.0-must-moved-20181128, sbws...
# 41   tor-bwauth, sbws-1.0-must-moved-20181128, sbws...
# 44   easy, log, intro, fast-fix, 035-backport?, con...
# 47                              torsocks, syscall, 217
# 48                technical-debt, regression, 041-must
# 50                                   doc, 040-backport
# 51   041-proposed, 035-backport, 040-backport, cons...
# 53   ipv6, 041-proposed, tor-relay, tor-exit, revie...
# 54                                 tor-time, asn-merge
# 55   merge-after-0403-alpha, teor-merge, CI, PTs 02...
# 56                                                 NaN
# 57                            no-changes-version, docs
# 60   tor-bwauth, 040-backport, 035-backport, 034-ba...
# 61   tor-bwauth, sbws-1.0-must-moved-20181128, sbws...
# 62   consider-backport-after-authority-test, consid...
# 63           fast-fix, python3, asn-merge, nickm-merge
# 67                                 asn-merge, coverity
# 68       040-must, 040-backport, fast-fix, nickm-merge
# 70   040-must, 040-backport, fast-fix, tor-spec, ni...
# 71   tor-ci-speed, 034-backport, 035-backport, 040-...
# 72                   easy, doc, asn-merge, nickm-merge
# 75   tor-ci-fail-sometimes, fast-fix, 040-backport,...
# 76                                                 NaN
# 78                                           tor-needs
# 79                                         git-scripts
# 84                                                 NaN
# 85                                                 NaN
# 86                                                 NaN
# 87            doc, comment, technical-debt, tor-bwauth
# 89   tor-ci-fail-sometimes, 035-backport, 040-backp...
# 90                       dir-spec, easy, doc, fast-fix
# 91                     git-scripts shell dgoulet-merge
# 93   asn-merge coverity technical-debt defensive-pr...
# 94                        040-backport?? dgoulet-merge
# 95                                          tor-bwauth
# 97                                       dgoulet-merge
# 98   openssl ux usability 035-backport? 040-backpor...
# 102  041-proposed, tor-client, easy, logging, messa...
