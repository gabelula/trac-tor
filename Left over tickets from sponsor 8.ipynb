# %%
# sponsor 8 tickets for the network team
csv_path='/Users/gaba/Code/torproject/trac/datasets/s8_network.csv'

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
csv_file = pd.read_csv(csv_path)

# %%
csv_file
# Out:
#        id                                            Summary        Sponsor  \
# 0   27146  Mismatched digest in 0.3.3.9 and master mixed ...   Sponsor8-can
# 1   28558  Crash in memoize_protover_summary() when cache...       Sponsor8
# 2   10059  capture tor log messages before control connec...       Sponsor8
# 3   23289  Improving HS reachability for Orbot/Android users   Sponsor8-can
# 4   23508  large clock skews cause numerous bootstrap UX ...   Sponsor8-can
# 5   23573  Do we want to close all connections when tor c...       Sponsor8
# 6   23882  Investigate implementing a Rust allocator wrap...   Sponsor8-can
# 7   24061  Collect Baseline Measurements for Different An...       Sponsor8
# 8   28849  Handle dormant mode in process library and for...       Sponsor8
# 9    2681  brainstorm ways to let Tor clients use yesterd...   Sponsor8-can
# 10   7707         Impose a minimum write size for TLS writes   Sponsor8-can
# 11   7743               Avoid needless wasted space in cells   Sponsor8-can
# 12   7747  SENDME doesn't need to trigger packaging so ag...   Sponsor8-can
# 13  10510      Getting a lot of system clock jumped messages   Sponsor8-can
# 14  11966  "Bootstrapped 20%: Asking for networkstatus co...   Sponsor8-can
# 15  16387  Improve reachability of hidden services on mob...   Sponsor8-can
# 16  17520         Relax the rend cache failure cleanup timer   Sponsor8-can
# 17  19522  HS intro circuit retry logic fails when networ...   Sponsor8-can
# 18  19665                    Should *Port_set count sockets?       Sponsor8
# 19  21358  Tor fails to reconnect after computer resumes ...   Sponsor8-can
# 20  21814             Reduce binary size for client-only tor       Sponsor8
# 21  22704  Use mmaps to handle journalled microdesc/route...   Sponsor8-can
# 22  22705  When disk space is low, rebuild main cached-* ...   Sponsor8-can
# 23  22707   Lower descriptor lifetime when disk space is low   Sponsor8-can
# 24  22758  When starting with no authority certificates, ...   Sponsor8-can
# 25  23221           Implement download resumption if needed.   Sponsor8-can
# 26  23521  detect if clock skew is probably really time z...       Sponsor8
# 27  23677  Tor should log what it thinks the time is some...   Sponsor8-can
# 28  23878                Attempt rewriting buffers.c in Rust   Sponsor8-can
# 29  24062             CPU profiling of Tor on Android device       Sponsor8
# ..    ...                                                ...            ...
# 56  26070  Remove remaining items from second_elapsed_cal...   Sponsor8-can
# 57  26337  Investigate making rust error types use the fa...   Sponsor8-can
# 58  26376                           add cross compiling docs   Sponsor8-can
# 59  26578  Do clients request new consensus documents mor...   Sponsor8-can
# 60  26999         tor_api: Some way to capture stdout/stderr   Sponsor8-can
# 61  27241  Extract information from more kinds of wedged ...   Sponsor8-can
# 62  27243    Keep much less directory info in RAM on clients       Sponsor8
# 63  27245  Don't store (micro)descriptor text on the heap...   Sponsor8-can
# 64  27248  Can we make our node-related structures more e...   Sponsor8-can
# 65  27381  Bad consensus diffs on 0.3.4 and later [with c...   Sponsor8-can
# 66  27563  cached_dir_t for consensus is redundant with c...   Sponsor8-can
# 67  27691  reset bootstrap progress when enough things ch...   Sponsor8-can
# 68  27801              tor_api: CreateConnection() interface   Sponsor8-can
# 69  28179  Handle output from PT processes with the event...  Sponsor8-must
# 70  28203  Make chutney log the bootstrap progress for ea...   Sponsor8-can
# 71  28226  Backend for an async publish-subcribe messagin...       Sponsor8
# 72  28348  Setting DisableNetwork won't disable NEED_NET ...       Sponsor8
# 73  28351            Test clock skewed clients using chutney   Sponsor8-can
# 74  28363  Make a torrc option which prevents Tor from fa...   Sponsor8-can
# 75  28423  improve precision of finegrained periodic even...       Sponsor8
# 76  28424  Refactor hs_service_callback() to no longer ne...   Sponsor8-can
# 77  28481    Tor's startup time is getting slower on Android   Sponsor8-can
# 78  28591            Accept a future consensus for bootstrap   Sponsor8-can
# 79  28702                        bootstrapping slow at times   Sponsor8-can
# 80  28703      bootstrapping very slow with filtered network   Sponsor8-can
# 81  28837  Use openssl's SHA3 implementations when they a...   Sponsor8-can
# 82  28845  evloop could be better at handling fork() in t...       Sponsor8
# 83  28926  improve reporting of directory bootstrap progress   Sponsor8-can
# 84   2915       Explore options to reduce binary size of Tor   Sponsor8-can
# 85  22706          Compress cached descriptors and consensus   Sponsor8-can
#
#            Component             Status    Owner         Type   Priority  \
# 0       Core Tor/Tor           assigned     teor       defect  Very High
# 1       Core Tor/Tor           assigned    nickm       defect  Very High
# 2       Core Tor/Tor                new    nickm  enhancement       High
# 3       Core Tor/Tor                new    n8fr8  enhancement       High
# 4       Core Tor/Tor                new      NaN       defect       High
# 5       Core Tor/Tor     needs_revision      NaN  enhancement       High
# 6       Core Tor/Tor                new      NaN  enhancement       High
# 7       Core Tor/Tor           assigned      ahf      project       High
# 8       Core Tor/Tor                new      NaN  enhancement       High
# 9       Core Tor/Tor                new      NaN  enhancement     Medium
# 10      Core Tor/Tor  needs_information      NaN       defect     Medium
# 11      Core Tor/Tor     needs_revision    nickm       defect     Medium
# 12      Core Tor/Tor                new      NaN       defect     Medium
# 13      Core Tor/Tor                new      NaN       defect     Medium
# 14      Core Tor/Tor     needs_revision      NaN       defect     Medium
# 15      Core Tor/Tor                new      NaN  enhancement     Medium
# 16      Core Tor/Tor  needs_information     neel  enhancement     Medium
# 17      Core Tor/Tor     needs_revision      NaN       defect     Medium
# 18      Core Tor/Tor                new      NaN       defect     Medium
# 19      Core Tor/Tor                new      NaN       defect     Medium
# 20      Core Tor/Tor                new      NaN         task     Medium
# 21      Core Tor/Tor                new      NaN  enhancement     Medium
# 22      Core Tor/Tor                new      NaN  enhancement     Medium
# 23      Core Tor/Tor                new      NaN  enhancement     Medium
# 24      Core Tor/Tor                new      NaN       defect     Medium
# 25      Core Tor/Tor                new      NaN  enhancement     Medium
# 26      Core Tor/Tor                new      NaN  enhancement     Medium
# 27      Core Tor/Tor                new      NaN       defect     Medium
# 28      Core Tor/Tor                new      NaN  enhancement     Medium
# 29      Core Tor/Tor           assigned      ahf         task     Medium
# ..               ...                ...      ...          ...        ...
# 56      Core Tor/Tor                new      NaN  enhancement     Medium
# 57      Core Tor/Tor  needs_information      NaN  enhancement     Medium
# 58      Core Tor/Tor  needs_information  Hello71  enhancement     Medium
# 59      Core Tor/Tor                new      NaN       defect     Medium
# 60      Core Tor/Tor                new      NaN  enhancement     Medium
# 61      Core Tor/Tor  needs_information    nickm  enhancement     Medium
# 62      Core Tor/Tor                new      NaN       defect     Medium
# 63      Core Tor/Tor           accepted    nickm       defect     Medium
# 64      Core Tor/Tor                new      NaN       defect     Medium
# 65      Core Tor/Tor           assigned     teor       defect     Medium
# 66      Core Tor/Tor                new      NaN  enhancement     Medium
# 67      Core Tor/Tor                new      NaN  enhancement     Medium
# 68      Core Tor/Tor                new      NaN  enhancement     Medium
# 69      Core Tor/Tor           assigned      ahf  enhancement     Medium
# 70  Core Tor/Chutney           assigned     teor       defect     Medium
# 71      Core Tor/Tor       needs_review    nickm  enhancement     Medium
# 72      Core Tor/Tor        merge_ready      NaN       defect     Medium
# 73  Core Tor/Chutney           assigned     teor  enhancement     Medium
# 74      Core Tor/Tor           assigned     arma  enhancement     Medium
# 75      Core Tor/Tor           assigned    nickm       defect     Medium
# 76      Core Tor/Tor                new      NaN       defect     Medium
# 77      Core Tor/Tor                new      NaN       defect     Medium
# 78      Core Tor/Tor        merge_ready     teor       defect     Medium
# 79      Core Tor/Tor                new      NaN       defect     Medium
# 80      Core Tor/Tor                new      NaN       defect     Medium
# 81      Core Tor/Tor       needs_review    nickm  enhancement     Medium
# 82      Core Tor/Tor                new      NaN  enhancement     Medium
# 83      Core Tor/Tor                new      NaN  enhancement     Medium
# 84      Core Tor/Tor                new      NaN  enhancement        Low
# 85      Core Tor/Tor                new      NaN  enhancement        Low
#
#              Milestone Severity  \
# 0   Tor: 0.3.5.x-final   Normal
# 1   Tor: 0.4.0.x-final   Normal
# 2     Tor: unspecified   Normal
# 3     Tor: unspecified   Normal
# 4     Tor: unspecified    Major
# 5   Tor: 0.3.5.x-final   Normal
# 6   Tor: 0.4.0.x-final   Normal
# 7     Tor: unspecified   Normal
# 8   Tor: 0.4.0.x-final   Normal
# 9     Tor: unspecified   Normal
# 10    Tor: unspecified   Normal
# 11    Tor: unspecified   Normal
# 12    Tor: unspecified   Normal
# 13    Tor: unspecified   Normal
# 14  Tor: 0.4.0.x-final   Normal
# 15    Tor: unspecified   Normal
# 16  Tor: 0.4.0.x-final   Normal
# 17    Tor: unspecified   Normal
# 18    Tor: unspecified   Normal
# 19    Tor: unspecified   Normal
# 20  Tor: 0.4.0.x-final   Normal
# 21    Tor: unspecified   Normal
# 22    Tor: unspecified   Normal
# 23    Tor: unspecified   Normal
# 24    Tor: unspecified   Normal
# 25    Tor: unspecified   Normal
# 26    Tor: unspecified   Normal
# 27    Tor: unspecified   Normal
# 28    Tor: unspecified   Normal
# 29    Tor: unspecified   Normal
# ..                 ...      ...
# 56    Tor: unspecified   Normal
# 57    Tor: unspecified   Normal
# 58  Tor: 0.4.0.x-final   Normal
# 59  Tor: 0.4.0.x-final   Normal
# 60    Tor: unspecified   Normal
# 61  Tor: 0.4.0.x-final   Normal
# 62  Tor: 0.4.0.x-final   Normal
# 63    Tor: unspecified   Normal
# 64  Tor: 0.4.0.x-final   Normal
# 65  Tor: 0.3.5.x-final   Normal
# 66  Tor: 0.4.0.x-final   Normal
# 67  Tor: 0.4.0.x-final   Normal
# 68  Tor: 0.4.0.x-final   Normal
# 69  Tor: 0.4.0.x-final   Normal
# 70                 NaN   Normal
# 71  Tor: 0.4.0.x-final   Normal
# 72  Tor: 0.3.4.x-final   Normal
# 73                 NaN   Normal
# 74    Tor: unspecified   Normal
# 75  Tor: 0.4.0.x-final   Normal
# 76  Tor: 0.4.0.x-final   Normal
# 77  Tor: 0.4.0.x-final   Normal
# 78  Tor: 0.3.5.x-final   Normal
# 79    Tor: unspecified   Normal
# 80    Tor: unspecified   Normal
# 81  Tor: 0.4.0.x-final   Normal
# 82  Tor: 0.4.0.x-final   Normal
# 83    Tor: unspecified   Normal
# 84    Tor: unspecified   Normal
# 85    Tor: unspecified   Normal
#
#                                              Keywords
# 0   regression, tor-dirauth, macOS, 035-roadmap-pr...
# 1                                                 NaN
# 2   tbb-usability, extdev-interview, tbb-needs, 03...
# 3   orbot, mobile, android, 034-triage-20180328, 0...
# 4   bootstrap, clock-skew, usability, ux, 032-unre...
# 5   shutdown, privcount, correctness, chutney-want...
# 6   rust, rust-pilot, 034-triage-20180328, 034-rem...
# 7   s8-perf, s8-201710, 034-triage-20180328, 034-r...
# 8                                                 NaN
# 9   prop212, tor-client, small-feature, tor-dos-di...
# 10  tor-relay, performance, bwbug, bandwidth spons...
# 11            tor-relay, bwbug, nagle, sponsor8-maybe
# 12  tor-relay, sendme, nagle, bandwidth, sponsor8-...
# 13  tor-relay, tor-client, sponsor8-maybe, timekee...
# 14  tor-bridge, sponsor8-maybe, bootstrap, 033-tri...
# 15  tor-hs, sponsor8-maybe, 034-triage-20180328, 0...
# 16                        tor-hs, tor-client, prop224
# 17            tor-hs tor-retry bootstrap network-down
# 18    tor-control technical-debt config torrc startup
# 19  sleep, wakeup, power-management, online-detect...
# 20  034-triage-20180328, 034-removed-20180328, 035...
# 21  sponsor8-maybe, mmap, 034-triage-20180328, 034...
# 22  sponsor8-maybe, disk-usage, 034-triage-2018032...
# 23  sponsor8-maybe, diskspace, 034-triage-20180328...
# 24  sponsor8-maybe, startup, bootstrap, time-to-fi...
# 25          034-triage-20180328, 034-removed-20180328
# 26  bootstrap, clock-skew, ux, s8-errors, 034-tria...
# 27  bootstrap, clock-skew, ux, s8-errors, 034-tria...
# 28  rust-pilot, rust, datatypes, 034-triage-201803...
# 29  s8-perf, s8-201710, 034-triage-20180328, 034-r...
# ..                                                ...
# 56                               035-removed-20180711
# 57  rust, technical-debt, tor-modularity, 035-remo...
# 58                                                NaN
# 59                                                NaN
# 60                                                NaN
# 61                    fast-fix, 035-deferred-20180930
# 62        035-roadmap-master, 035-triaged-in-20180711
# 63        035-roadmap-master, 035-triaged-in-20180711
# 64        035-roadmap-master, 035-triaged-in-20180711
# 65                                           tor-auth
# 66                                                NaN
# 67  usability, ux, ux-team, bootstrap, 035-roadmap...
# 68                                                NaN
# 69                        tor-pt, 040-roadmap-subtask
# 70  test, chutney, consistency, jenkins, integrati...
# 71                                         tor-pubsub
# 72                                       034-backport
# 73  bootstrap, clock-skew, tor-guard, usability, u...
# 74                                                NaN
# 75                                                NaN
# 76                                                NaN
# 77             android startup performance controller
# 78  bootstrap, clock-skew, tor-guard, usability, u...
# 79                                 s8-bootstrap-maybe
# 80                                 s8-bootstrap-maybe
# 81             android startup performance controller
# 82                                                NaN
# 83                        s8-bootstrap, ux, directory
# 84  tor-client, modularity, download-size, memory,...
# 85  sponsor8-maybe, disk-usage, 034-triage-2018032...
#
# [86 rows x 11 columns]

# %%
# How many tickets left over on must do or can do
csv_file['Sponsor'].value_counts() #.index.tolist()
# Out:
# Sponsor8-can     58
# Sponsor8         26
# Sponsor8-must     2
# Name: Sponsor, dtype: int64

# %%
# who got the most
csv_file['Owner'].value_counts()
# Out:
# ahf        11
# nickm      10
# teor        6
# dgoulet     1
# n8fr8       1
# neel        1
# arma        1
# Hello71     1
# Name: Owner, dtype: int64

# %%
# What type of tickets we got
csv_file['Type'].value_counts()
# Out:
# enhancement    39
# defect         34
# task           10
# project         3
# Name: Type, dtype: int64

# %%
# How many high and very high tickets
csv_file['Priority'].value_counts()
# Out:
# Medium       75
# High          7
# Very High     2
# Low           2
# Name: Priority, dtype: int64

# %%
# which milestone the tickets were supposed to be for
csv_file['Milestone'].value_counts()
# Out:
# Tor: unspecified      45
# Tor: 0.4.0.x-final    31
# Tor: 0.3.5.x-final     6
# Tor: 0.3.4.x-final     1
# Name: Milestone, dtype: int64

# %%
# in which status the tickets were left
csv_file['Status'].value_counts()
# Out:
# new                  49
# assigned             22
# needs_information     5
# needs_revision        4
# merge_ready           3
# needs_review          2
# accepted              1
# Name: Status, dtype: int64
